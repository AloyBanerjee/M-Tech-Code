# %%
# !pip install --quiet mrjob

# %%
import os 
os.chdir('C:/Users/Admin/Coding-M-Tech/AI Lab 2 - ID5003W/Assignment 1/Test for Vinu')

# %%
# %%file test.py

import os
from mrjob.job import MRJob
from mrjob.step import MRStep

class MaxSentenceLength(MRJob):

    def mapper_init(self):
        self.current_sentence = ''

    def mapper(self, _, value):
        file_name, line = os.getenv('mapreduce_map_input_file'), ' '.join(value.encode("ascii", "ignore").decode().split())
        if '.' in line:      
            dot_split = line.split('.')
            current_sentence = self.current_sentence + ' ' if self.current_sentence else ''    
            self.current_sentence = '. '.join(dot_split[1:]) if len(dot_split) > 1 else ''
            yield file_name, max((current_sentence + ' ' + dot_split[0]).split('. '))
        else:
            self.current_sentence += ' ' + line if line != '' else '. ' + line

    def reducer(self, key, values):
        sentence = max(list(values), key=len)
        sentence_length = len(sentence)
        yield key, f"Maximum length of sentence is {sentence_length} from {key} file. Longest Sentence of {key} file is :{sentence}"

    def steps(self):
        return [
            MRStep(mapper_init=self.mapper_init, mapper=self.mapper, reducer=self.reducer)
        ]

if __name__ == '__main__':
    MaxSentenceLength.run()
# Out:
# Overwriting test.py

# %%
# !python test.py --mapper < "pg2600.txt"
# Out:
# null	" This eBook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions  whatsoever"
# null	" You may copy it, give it away or re-use it under the terms of the Project Gutenberg License included with this eBook or online at  www"
# null	"org"
# null	" Well, Prince, so Genoa and Lucca are now just family estates of the  Buonapartes"
# null	" But I warn you, if you dont tell me that this means war, if you still try to defend the infamies and horrors perpetrated by that AntichristI really believe he is AntichristI will have nothing more to do with you and you are no longer my friend, no longer my faithful slave, as you call yourself! But how do you do? I see I  have frightened yousit down and tell me all the news"
# null	" It was in July, 1805, and the speaker was the well-known Anna Pvlovna  Schrer, maid of honor and favorite of the Empress Mrya Fdorovna"
# ...

# %%
# !python test.py "test.txt"
# Out:
# "file:\/\/test.txt"	"Maximum length of sentence is 26 from file:\/\/test.txt file. Longest Sentence of file:\/\/test.txt file is : freely shared with anyone"
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\Admin\AppData\Local\Temp\test.Admin.20230531.153410.062064
# Running step 1 of 1...
# job output is in C:\Users\Admin\AppData\Local\Temp\test.Admin.20230531.153410.062064\output
# Streaming final output from C:\Users\Admin\AppData\Local\Temp\test.Admin.20230531.153410.062064\output...
# Removing temp directory C:\Users\Admin\AppData\Local\Temp\test.Admin.20230531.153410.062064...

# %%
        #yield file_name, value
