# %%
import numpy as np
import pandas as pd

# Load measurements from CSV file
measurements = pd.read_excel('/content/Link 2 Measurements.xlsx')
# time_stamps = measurements['timestamp'].values
z_true = measurements[['h1', 'h2', 'h3', 'h4']].values

# Initialize variables
n_states = 4
A = np.eye(n_states)
B = np.eye(n_states)
u = np.zeros((n_states,))

X_post = np.array([1, 1, 1, 1]).reshape(-1, 1)
P_post = 1e5 * np.eye(n_states)

Q = 10 * np.eye(n_states)
R = 2 * np.eye(n_states)

# Kalman filter loop
for k in range(len(z_true)):
    # Prediction step
    X_pri = A.dot(X_post) + B.dot(u)
    P_pri = A.dot(P_post).dot(A.T) + Q

    # Update step
    H = np.eye(n_states)
    K = P_pri.dot(H.T) / (H.dot(P_pri).dot(H.T) + R)

    Z_est = H.dot(X_pri)
    E = z_true[k].reshape(-1, 1) - Z_est

    X_post = X_pri + K.dot(E)
    P_post = P_pri - K.dot(H).dot(P_pri)

    # Check for convergence (X_post - X_pri)
    if np.allclose(X_post, X_pri):
        break

# Print the estimated values
print('Estimated values:')
for i, tank in enumerate(['h1', 'h2', 'h3', 'h4']):
    print(f'{tank}: {X_post[i][0]}')
# Out:
# <ipython-input-4-29b89f1492c9>:29: RuntimeWarning: invalid value encountered in true_divide
#   K = P_pri.dot(H.T) / (H.dot(P_pri).dot(H.T) + R)
# Estimated values:
# h1: nan
# h2: nan
# h3: nan
# h4: nan

# %% [markdown]
# ##AIPM-MINI_PROJECT ON ESTIMATING HEIGHTS OF WATER TANKS
# ##BY CH22M522

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##PROBLEM-1

# %% [markdown]
# ###### Problem - 1: Kalman Filter
# ###### Implement the Kalman Filter to estimate the level of water in the 4 tanks present in the Quadruple tank experiment, as discussed in class. The experiment is explained in detail in the reference paper (Quadruple tank process) as in the link given below.
# ###### Link: https://drive.google.com/file/d/1XQ-O1Rov4L_b6n1J6dJQ7_3cUy-l-ik4/view?usp=sharing
# ###### Please use the same parameter values as described in the paper. For the initial conditions, use the minimum-phase characteristic values. The transfer functions given in the paper can be ignored for this assignment. Q and R values have to be tuned to attain convergence of the filter and get better accuracy with the estimates. Tolerance, defined as the L2 norm between prior and posterior state vectors, has to be less than or equal to 5 X 10-3. Measurements are sampled at a time interval of 0.1s. Measurement values obtained by solving the model equations have also been uploaded in the link given below. Use them as the true measurements.
# ###### Link: https://docs.google.com/spreadsheets/d/10lm7KOxo6k3etXTsW5t2KYcC7d0sGUlZ/edit?usp=sharing&ouid=108491382124139074371&rtpof=true&sd=true

# %% [markdown]
# ANALYSING DATA FROM THE CSV FILE

# %%
# Load measurements from CSV file
measurements = pd.read_excel('/content/Link 2 Measurements.xlsx')
# time_stamps = measurements['timestamp'].values
z_true = measurements[['h1', 'h2', 'h3', 'h4']].values

# %%
z_true[1,:4].reshape(-1,1)
# Out:
# array([[12.40492766],
#        [12.70061798],
#        [ 1.79288086],
#        [ 1.40030108]])

# %%
measurements.head()
# Out:
#           h1         h2        h3        h4
# 0  12.400000  12.700000  1.800000  1.400000
# 1  12.404928  12.700618  1.792881  1.400301
# 2  12.409478  12.701239  1.786060  1.400592
# 3  12.413670  12.701863  1.779526  1.400873
# 4  12.417521  12.702490  1.773266  1.401145

# %% [markdown]
# Finding out the Kalman filter variables such as T, state matrices-A,B,C as given in research paper

# %%
h=[12.4,12.7,1.8,1.4]
Ar=[28,32,28,32]
ar=[0.071,0.057,0.071,0.057]
g=981.2
T=[]
for i in range(len(h)):
  Time_const=(Ar[i]/ar[i])*np.sqrt((2*h[i])/g)
  T.append(Time_const)

print(T)
# Out:
# [62.69699892820124, 90.32609002462239, 23.887580479237094, 29.989924232904087]

# %%
gamma_1=0.7
gamma_2=0.6
k1=3.33
k2=3.35

# %%
A=[[-1/T[0],0,(Ar[2]/(Ar[0]*T[2])),0],[0,-1/T[1],0,(Ar[3]/(Ar[1]*T[3]))],[0,0,-1/T[2],0],[0,0,0,-1/T[3]]]

# %%
B=[[(gamma_1*k1)/Ar[0],0],[0,(gamma_2*k2)/Ar[1]],[0,((1-gamma_2)*k2)/Ar[2]],[((1-gamma_1)*k1)/Ar[3],0]]

# %%
u=np.array([[3],[3]])

# %%
u.shape
# Out:
# (2, 1)

# %% [markdown]
# Converting A and B into np.array

# %%
A=np.array(A)
B=np.array(B)

# %% [markdown]
# Now applying Kalman Filter

# %%
# Initialize variables
dt = 0.1
num_tanks = 4
num_measurements = len(z_true)
# A = np.eye(num_tanks)  # Transition matrix
# B = np.eye(num_tanks)  # Input matrix
# u = np.zeros((num_tanks, num_measurements))  # Input vector
X_post = np.ones((num_tanks, 1))  # Initial state estimate
P_post = 1e5 * np.eye(num_tanks)  # Initial error covariance
Q = 8* np.eye(num_tanks)  # Process noise covariance
R = 2 * np.eye(4)  # Measurement noise covariance

# Define the measurement matrix
# H = np.eye(num_tanks)
kc=0.5
H=[[kc,0,0,0],[0,kc,0,0],[0,0,kc,0],[0,0,0,kc]]
H=np.array(H)
# Initialize lists to store values for plotting
X_post_list = []
P_post_list = []
P_pri_list = []
Kalman_gain_list = []

x_post_old = np.zeros(num_measurements)
# Kalman filter loop
for k in range(num_measurements):
    # Prediction step
    X_pri = np.dot(A, X_post) + np.dot(B, u[:].reshape(-1, 1))
    P_pri = np.dot(np.dot(A, P_post), A.T) + Q

    # Update step
    K = np.dot(np.dot(P_pri, H.T), np.linalg.inv(np.dot(np.dot(H, P_pri), H.T) + R))
    Z_est = np.dot(H, X_pri)
    E = z_true[k,:4] - Z_est.flatten()
    X_post = X_pri + np.dot(K, E.reshape(-1, 1))
    P_post = P_pri - np.dot(np.dot(K, H), P_pri)

    # Append values to the lists
    X_post_list.append(X_post.flatten())
    P_post_list.append(np.trace(P_post))
    P_pri_list.append(np.trace(P_pri))
    Kalman_gain_list.append(np.trace(K))

    # Calculate the L2 norm

    l2_norm = np.linalg.norm(x_post_old - X_post)
    x_post_old = X_post

    # Check if the L2 norm is less than or equal to the threshold
    threshold = 5e-3
    if l2_norm <= threshold:
        print(f"L2 norm converges to threshold value at {k} iteration")


    # Stop condition: X_post - X_pri approx = 0
    if np.allclose(X_post, X_pri):
        break

# Final estimated states
estimated_states = X_post.flatten()
print("Estimated states:", estimated_states)
# Out:
# Streaming output truncated to the last 5000 lines.
# L2 norm converges to threshold value at 5002 iteration
# L2 norm converges to threshold value at 5003 iteration
# L2 norm converges to threshold value at 5004 iteration
# L2 norm converges to threshold value at 5005 iteration
# L2 norm converges to threshold value at 5006 iteration
# L2 norm converges to threshold value at 5007 iteration
# L2 norm converges to threshold value at 5008 iteration
# L2 norm converges to threshold value at 5009 iteration
# L2 norm converges to threshold value at 5010 iteration
# L2 norm converges to threshold value at 5011 iteration
# L2 norm converges to threshold value at 5012 iteration
# L2 norm converges to threshold value at 5013 iteration
# L2 norm converges to threshold value at 5014 iteration
# L2 norm converges to threshold value at 5015 iteration
# L2 norm converges to threshold value at 5016 iteration
# L2 norm converges to threshold value at 5017 iteration
# L2 norm converges to threshold value at 5018 iteration
# L2 norm converges to threshold value at 5019 iteration
# L2 norm converges to threshold value at 5020 iteration
# L2 norm converges to threshold value at 5021 iteration
# L2 norm converges to threshold value at 5022 iteration
# L2 norm converges to threshold value at 5023 iteration
# L2 norm converges to threshold value at 5024 iteration
# L2 norm converges to threshold value at 5025 iteration
# L2 norm converges to threshold value at 5026 iteration
# L2 norm converges to threshold value at 5027 iteration
# L2 norm converges to threshold value at 5028 iteration
# L2 norm converges to threshold value at 5029 iteration
# L2 norm converges to threshold value at 5030 iteration
# L2 norm converges to threshold value at 5031 iteration
# L2 norm converges to threshold value at 5032 iteration
# L2 norm converges to threshold value at 5033 iteration
# L2 norm converges to threshold value at 5034 iteration
# L2 norm converges to threshold value at 5035 iteration
# L2 norm converges to threshold value at 5036 iteration
# L2 norm converges to threshold value at 5037 iteration
# L2 norm converges to threshold value at 5038 iteration
# L2 norm converges to threshold value at 5039 iteration
# L2 norm converges to threshold value at 5040 iteration
# L2 norm converges to threshold value at 5041 iteration
# L2 norm converges to threshold value at 5042 iteration
# L2 norm converges to threshold value at 5043 iteration
# L2 norm converges to threshold value at 5044 iteration
# L2 norm converges to threshold value at 5045 iteration
# L2 norm converges to threshold value at 5046 iteration
# L2 norm converges to threshold value at 5047 iteration
# L2 norm converges to threshold value at 5048 iteration
# L2 norm converges to threshold value at 5049 iteration
# L2 norm converges to threshold value at 5050 iteration
# L2 norm converges to threshold value at 5051 iteration
# L2 norm converges to threshold value at 5052 iteration
# L2 norm converges to threshold value at 5053 iteration
# L2 norm converges to threshold value at 5054 iteration
# L2 norm converges to threshold value at 5055 iteration
# L2 norm converges to threshold value at 5056 iteration
# L2 norm converges to threshold value at 5057 iteration
# L2 norm converges to threshold value at 5058 iteration
# L2 norm converges to threshold value at 5059 iteration
# L2 norm converges to threshold value at 5060 iteration
# L2 norm converges to threshold value at 5061 iteration
# L2 norm converges to threshold value at 5062 iteration
# L2 norm converges to threshold value at 5063 iteration
# L2 norm converges to threshold value at 5064 iteration
# L2 norm converges to threshold value at 5065 iteration
# L2 norm converges to threshold value at 5066 iteration
# L2 norm converges to threshold value at 5067 iteration
# L2 norm converges to threshold value at 5068 iteration
# L2 norm converges to threshold value at 5069 iteration
# L2 norm converges to threshold value at 5070 iteration
# L2 norm converges to threshold value at 5071 iteration
# L2 norm converges to threshold value at 5072 iteration
# L2 norm converges to threshold value at 5073 iteration
# L2 norm converges to threshold value at 5074 iteration
# L2 norm converges to threshold value at 5075 iteration
# L2 norm converges to threshold value at 5076 iteration
# L2 norm converges to threshold value at 5077 iteration
# L2 norm converges to threshold value at 5078 iteration
# L2 norm converges to threshold value at 5079 iteration
# L2 norm converges to threshold value at 5080 iteration
# L2 norm converges to threshold value at 5081 iteration
# L2 norm converges to threshold value at 5082 iteration
# L2 norm converges to threshold value at 5083 iteration
# L2 norm converges to threshold value at 5084 iteration
# L2 norm converges to threshold value at 5085 iteration
# L2 norm converges to threshold value at 5086 iteration
# L2 norm converges to threshold value at 5087 iteration
# L2 norm converges to threshold value at 5088 iteration
# L2 norm converges to threshold value at 5089 iteration
# L2 norm converges to threshold value at 5090 iteration
# L2 norm converges to threshold value at 5091 iteration
# L2 norm converges to threshold value at 5092 iteration
# L2 norm converges to threshold value at 5093 iteration
# L2 norm converges to threshold value at 5094 iteration
# L2 norm converges to threshold value at 5095 iteration
# L2 norm converges to threshold value at 5096 iteration
# L2 norm converges to threshold value at 5097 iteration
# L2 norm converges to threshold value at 5098 iteration
# L2 norm converges to threshold value at 5099 iteration
# L2 norm converges to threshold value at 5100 iteration
# L2 norm converges to threshold value at 5101 iteration
# L2 norm converges to threshold value at 5102 iteration
# L2 norm converges to threshold value at 5103 iteration
# L2 norm converges to threshold value at 5104 iteration
# L2 norm converges to threshold value at 5105 iteration
# L2 norm converges to threshold value at 5106 iteration
# L2 norm converges to threshold value at 5107 iteration
# L2 norm converges to threshold value at 5108 iteration
# L2 norm converges to threshold value at 5109 iteration
# L2 norm converges to threshold value at 5110 iteration
# L2 norm converges to threshold value at 5111 iteration
# L2 norm converges to threshold value at 5112 iteration
# L2 norm converges to threshold value at 5113 iteration
# L2 norm converges to threshold value at 5114 iteration
# L2 norm converges to threshold value at 5115 iteration
# L2 norm converges to threshold value at 5116 iteration
# L2 norm converges to threshold value at 5117 iteration
# L2 norm converges to threshold value at 5118 iteration
# L2 norm converges to threshold value at 5119 iteration
# L2 norm converges to threshold value at 5120 iteration
# L2 norm converges to threshold value at 5121 iteration
# L2 norm converges to threshold value at 5122 iteration
# L2 norm converges to threshold value at 5123 iteration
# L2 norm converges to threshold value at 5124 iteration
# L2 norm converges to threshold value at 5125 iteration
# L2 norm converges to threshold value at 5126 iteration
# L2 norm converges to threshold value at 5127 iteration
# L2 norm converges to threshold value at 5128 iteration
# L2 norm converges to threshold value at 5129 iteration
# L2 norm converges to threshold value at 5130 iteration
# L2 norm converges to threshold value at 5131 iteration
# L2 norm converges to threshold value at 5132 iteration
# L2 norm converges to threshold value at 5133 iteration
# L2 norm converges to threshold value at 5134 iteration
# L2 norm converges to threshold value at 5135 iteration
# L2 norm converges to threshold value at 5136 iteration
# L2 norm converges to threshold value at 5137 iteration
# L2 norm converges to threshold value at 5138 iteration
# L2 norm converges to threshold value at 5139 iteration
# L2 norm converges to threshold value at 5140 iteration
# L2 norm converges to threshold value at 5141 iteration
# L2 norm converges to threshold value at 5142 iteration
# L2 norm converges to threshold value at 5143 iteration
# L2 norm converges to threshold value at 5144 iteration
# L2 norm converges to threshold value at 5145 iteration
# L2 norm converges to threshold value at 5146 iteration
# L2 norm converges to threshold value at 5147 iteration
# L2 norm converges to threshold value at 5148 iteration
# L2 norm converges to threshold value at 5149 iteration
# L2 norm converges to threshold value at 5150 iteration
# L2 norm converges to threshold value at 5151 iteration
# L2 norm converges to threshold value at 5152 iteration
# L2 norm converges to threshold value at 5153 iteration
# L2 norm converges to threshold value at 5154 iteration
# L2 norm converges to threshold value at 5155 iteration
# L2 norm converges to threshold value at 5156 iteration
# L2 norm converges to threshold value at 5157 iteration
# L2 norm converges to threshold value at 5158 iteration
# L2 norm converges to threshold value at 5159 iteration
# L2 norm converges to threshold value at 5160 iteration
# L2 norm converges to threshold value at 5161 iteration
# L2 norm converges to threshold value at 5162 iteration
# L2 norm converges to threshold value at 5163 iteration
# L2 norm converges to threshold value at 5164 iteration
# L2 norm converges to threshold value at 5165 iteration
# L2 norm converges to threshold value at 5166 iteration
# L2 norm converges to threshold value at 5167 iteration
# L2 norm converges to threshold value at 5168 iteration
# L2 norm converges to threshold value at 5169 iteration
# L2 norm converges to threshold value at 5170 iteration
# L2 norm converges to threshold value at 5171 iteration
# L2 norm converges to threshold value at 5172 iteration
# L2 norm converges to threshold value at 5173 iteration
# L2 norm converges to threshold value at 5174 iteration
# L2 norm converges to threshold value at 5175 iteration
# L2 norm converges to threshold value at 5176 iteration
# L2 norm converges to threshold value at 5177 iteration
# L2 norm converges to threshold value at 5178 iteration
# L2 norm converges to threshold value at 5179 iteration
# L2 norm converges to threshold value at 5180 iteration
# L2 norm converges to threshold value at 5181 iteration
# L2 norm converges to threshold value at 5182 iteration
# L2 norm converges to threshold value at 5183 iteration
# L2 norm converges to threshold value at 5184 iteration
# L2 norm converges to threshold value at 5185 iteration
# L2 norm converges to threshold value at 5186 iteration
# L2 norm converges to threshold value at 5187 iteration
# L2 norm converges to threshold value at 5188 iteration
# L2 norm converges to threshold value at 5189 iteration
# L2 norm converges to threshold value at 5190 iteration
# L2 norm converges to threshold value at 5191 iteration
# L2 norm converges to threshold value at 5192 iteration
# L2 norm converges to threshold value at 5193 iteration
# L2 norm converges to threshold value at 5194 iteration
# L2 norm converges to threshold value at 5195 iteration
# L2 norm converges to threshold value at 5196 iteration
# L2 norm converges to threshold value at 5197 iteration
# L2 norm converges to threshold value at 5198 iteration
# L2 norm converges to threshold value at 5199 iteration
# L2 norm converges to threshold value at 5200 iteration
# L2 norm converges to threshold value at 5201 iteration
# L2 norm converges to threshold value at 5202 iteration
# L2 norm converges to threshold value at 5203 iteration
# L2 norm converges to threshold value at 5204 iteration
# L2 norm converges to threshold value at 5205 iteration
# L2 norm converges to threshold value at 5206 iteration
# L2 norm converges to threshold value at 5207 iteration
# L2 norm converges to threshold value at 5208 iteration
# L2 norm converges to threshold value at 5209 iteration
# L2 norm converges to threshold value at 5210 iteration
# L2 norm converges to threshold value at 5211 iteration
# L2 norm converges to threshold value at 5212 iteration
# L2 norm converges to threshold value at 5213 iteration
# L2 norm converges to threshold value at 5214 iteration
# L2 norm converges to threshold value at 5215 iteration
# L2 norm converges to threshold value at 5216 iteration
# L2 norm converges to threshold value at 5217 iteration
# L2 norm converges to threshold value at 5218 iteration
# L2 norm converges to threshold value at 5219 iteration
# L2 norm converges to threshold value at 5220 iteration
# L2 norm converges to threshold value at 5221 iteration
# L2 norm converges to threshold value at 5222 iteration
# L2 norm converges to threshold value at 5223 iteration
# L2 norm converges to threshold value at 5224 iteration
# L2 norm converges to threshold value at 5225 iteration
# L2 norm converges to threshold value at 5226 iteration
# L2 norm converges to threshold value at 5227 iteration
# L2 norm converges to threshold value at 5228 iteration
# L2 norm converges to threshold value at 5229 iteration
# L2 norm converges to threshold value at 5230 iteration
# L2 norm converges to threshold value at 5231 iteration
# L2 norm converges to threshold value at 5232 iteration
# L2 norm converges to threshold value at 5233 iteration
# L2 norm converges to threshold value at 5234 iteration
# L2 norm converges to threshold value at 5235 iteration
# L2 norm converges to threshold value at 5236 iteration
# L2 norm converges to threshold value at 5237 iteration
# L2 norm converges to threshold value at 5238 iteration
# L2 norm converges to threshold value at 5239 iteration
# L2 norm converges to threshold value at 5240 iteration
# L2 norm converges to threshold value at 5241 iteration
# L2 norm converges to threshold value at 5242 iteration
# L2 norm converges to threshold value at 5243 iteration
# L2 norm converges to threshold value at 5244 iteration
# L2 norm converges to threshold value at 5245 iteration
# L2 norm converges to threshold value at 5246 iteration
# L2 norm converges to threshold value at 5247 iteration
# L2 norm converges to threshold value at 5248 iteration
# L2 norm converges to threshold value at 5249 iteration
# L2 norm converges to threshold value at 5250 iteration
# L2 norm converges to threshold value at 5251 iteration
# L2 norm converges to threshold value at 5252 iteration
# L2 norm converges to threshold value at 5253 iteration
# L2 norm converges to threshold value at 5254 iteration
# L2 norm converges to threshold value at 5255 iteration
# L2 norm converges to threshold value at 5256 iteration
# L2 norm converges to threshold value at 5257 iteration
# L2 norm converges to threshold value at 5258 iteration
# L2 norm converges to threshold value at 5259 iteration
# L2 norm converges to threshold value at 5260 iteration
# L2 norm converges to threshold value at 5261 iteration
# L2 norm converges to threshold value at 5262 iteration
# L2 norm converges to threshold value at 5263 iteration
# L2 norm converges to threshold value at 5264 iteration
# L2 norm converges to threshold value at 5265 iteration
# L2 norm converges to threshold value at 5266 iteration
# L2 norm converges to threshold value at 5267 iteration
# L2 norm converges to threshold value at 5268 iteration
# L2 norm converges to threshold value at 5269 iteration
# L2 norm converges to threshold value at 5270 iteration
# L2 norm converges to threshold value at 5271 iteration
# L2 norm converges to threshold value at 5272 iteration
# L2 norm converges to threshold value at 5273 iteration
# L2 norm converges to threshold value at 5274 iteration
# L2 norm converges to threshold value at 5275 iteration
# L2 norm converges to threshold value at 5276 iteration
# L2 norm converges to threshold value at 5277 iteration
# L2 norm converges to threshold value at 5278 iteration
# L2 norm converges to threshold value at 5279 iteration
# L2 norm converges to threshold value at 5280 iteration
# L2 norm converges to threshold value at 5281 iteration
# L2 norm converges to threshold value at 5282 iteration
# L2 norm converges to threshold value at 5283 iteration
# L2 norm converges to threshold value at 5284 iteration
# L2 norm converges to threshold value at 5285 iteration
# L2 norm converges to threshold value at 5286 iteration
# L2 norm converges to threshold value at 5287 iteration
# L2 norm converges to threshold value at 5288 iteration
# L2 norm converges to threshold value at 5289 iteration
# L2 norm converges to threshold value at 5290 iteration
# L2 norm converges to threshold value at 5291 iteration
# L2 norm converges to threshold value at 5292 iteration
# L2 norm converges to threshold value at 5293 iteration
# L2 norm converges to threshold value at 5294 iteration
# L2 norm converges to threshold value at 5295 iteration
# L2 norm converges to threshold value at 5296 iteration
# L2 norm converges to threshold value at 5297 iteration
# L2 norm converges to threshold value at 5298 iteration
# L2 norm converges to threshold value at 5299 iteration
# L2 norm converges to threshold value at 5300 iteration
# L2 norm converges to threshold value at 5301 iteration
# L2 norm converges to threshold value at 5302 iteration
# L2 norm converges to threshold value at 5303 iteration
# L2 norm converges to threshold value at 5304 iteration
# L2 norm converges to threshold value at 5305 iteration
# L2 norm converges to threshold value at 5306 iteration
# L2 norm converges to threshold value at 5307 iteration
# L2 norm converges to threshold value at 5308 iteration
# L2 norm converges to threshold value at 5309 iteration
# L2 norm converges to threshold value at 5310 iteration
# L2 norm converges to threshold value at 5311 iteration
# L2 norm converges to threshold value at 5312 iteration
# L2 norm converges to threshold value at 5313 iteration
# L2 norm converges to threshold value at 5314 iteration
# L2 norm converges to threshold value at 5315 iteration
# L2 norm converges to threshold value at 5316 iteration
# L2 norm converges to threshold value at 5317 iteration
# L2 norm converges to threshold value at 5318 iteration
# L2 norm converges to threshold value at 5319 iteration
# L2 norm converges to threshold value at 5320 iteration
# L2 norm converges to threshold value at 5321 iteration
# L2 norm converges to threshold value at 5322 iteration
# L2 norm converges to threshold value at 5323 iteration
# L2 norm converges to threshold value at 5324 iteration
# L2 norm converges to threshold value at 5325 iteration
# L2 norm converges to threshold value at 5326 iteration
# L2 norm converges to threshold value at 5327 iteration
# L2 norm converges to threshold value at 5328 iteration
# L2 norm converges to threshold value at 5329 iteration
# L2 norm converges to threshold value at 5330 iteration
# L2 norm converges to threshold value at 5331 iteration
# L2 norm converges to threshold value at 5332 iteration
# L2 norm converges to threshold value at 5333 iteration
# L2 norm converges to threshold value at 5334 iteration
# L2 norm converges to threshold value at 5335 iteration
# L2 norm converges to threshold value at 5336 iteration
# L2 norm converges to threshold value at 5337 iteration
# L2 norm converges to threshold value at 5338 iteration
# L2 norm converges to threshold value at 5339 iteration
# L2 norm converges to threshold value at 5340 iteration
# L2 norm converges to threshold value at 5341 iteration
# L2 norm converges to threshold value at 5342 iteration
# L2 norm converges to threshold value at 5343 iteration
# L2 norm converges to threshold value at 5344 iteration
# L2 norm converges to threshold value at 5345 iteration
# L2 norm converges to threshold value at 5346 iteration
# L2 norm converges to threshold value at 5347 iteration
# L2 norm converges to threshold value at 5348 iteration
# L2 norm converges to threshold value at 5349 iteration
# L2 norm converges to threshold value at 5350 iteration
# L2 norm converges to threshold value at 5351 iteration
# L2 norm converges to threshold value at 5352 iteration
# L2 norm converges to threshold value at 5353 iteration
# L2 norm converges to threshold value at 5354 iteration
# L2 norm converges to threshold value at 5355 iteration
# L2 norm converges to threshold value at 5356 iteration
# L2 norm converges to threshold value at 5357 iteration
# L2 norm converges to threshold value at 5358 iteration
# L2 norm converges to threshold value at 5359 iteration
# L2 norm converges to threshold value at 5360 iteration
# L2 norm converges to threshold value at 5361 iteration
# L2 norm converges to threshold value at 5362 iteration
# L2 norm converges to threshold value at 5363 iteration
# L2 norm converges to threshold value at 5364 iteration
# L2 norm converges to threshold value at 5365 iteration
# L2 norm converges to threshold value at 5366 iteration
# L2 norm converges to threshold value at 5367 iteration
# L2 norm converges to threshold value at 5368 iteration
# L2 norm converges to threshold value at 5369 iteration
# L2 norm converges to threshold value at 5370 iteration
# L2 norm converges to threshold value at 5371 iteration
# L2 norm converges to threshold value at 5372 iteration
# L2 norm converges to threshold value at 5373 iteration
# L2 norm converges to threshold value at 5374 iteration
# L2 norm converges to threshold value at 5375 iteration
# L2 norm converges to threshold value at 5376 iteration
# L2 norm converges to threshold value at 5377 iteration
# L2 norm converges to threshold value at 5378 iteration
# L2 norm converges to threshold value at 5379 iteration
# L2 norm converges to threshold value at 5380 iteration
# L2 norm converges to threshold value at 5381 iteration
# L2 norm converges to threshold value at 5382 iteration
# L2 norm converges to threshold value at 5383 iteration
# L2 norm converges to threshold value at 5384 iteration
# L2 norm converges to threshold value at 5385 iteration
# L2 norm converges to threshold value at 5386 iteration
# L2 norm converges to threshold value at 5387 iteration
# L2 norm converges to threshold value at 5388 iteration
# L2 norm converges to threshold value at 5389 iteration
# L2 norm converges to threshold value at 5390 iteration
# L2 norm converges to threshold value at 5391 iteration
# L2 norm converges to threshold value at 5392 iteration
# L2 norm converges to threshold value at 5393 iteration
# L2 norm converges to threshold value at 5394 iteration
# L2 norm converges to threshold value at 5395 iteration
# L2 norm converges to threshold value at 5396 iteration
# L2 norm converges to threshold value at 5397 iteration
# L2 norm converges to threshold value at 5398 iteration
# L2 norm converges to threshold value at 5399 iteration
# L2 norm converges to threshold value at 5400 iteration
# L2 norm converges to threshold value at 5401 iteration
# L2 norm converges to threshold value at 5402 iteration
# L2 norm converges to threshold value at 5403 iteration
# L2 norm converges to threshold value at 5404 iteration
# L2 norm converges to threshold value at 5405 iteration
# L2 norm converges to threshold value at 5406 iteration
# L2 norm converges to threshold value at 5407 iteration
# L2 norm converges to threshold value at 5408 iteration
# L2 norm converges to threshold value at 5409 iteration
# L2 norm converges to threshold value at 5410 iteration
# L2 norm converges to threshold value at 5411 iteration
# L2 norm converges to threshold value at 5412 iteration
# L2 norm converges to threshold value at 5413 iteration
# L2 norm converges to threshold value at 5414 iteration
# L2 norm converges to threshold value at 5415 iteration
# L2 norm converges to threshold value at 5416 iteration
# L2 norm converges to threshold value at 5417 iteration
# L2 norm converges to threshold value at 5418 iteration
# L2 norm converges to threshold value at 5419 iteration
# L2 norm converges to threshold value at 5420 iteration
# L2 norm converges to threshold value at 5421 iteration
# L2 norm converges to threshold value at 5422 iteration
# L2 norm converges to threshold value at 5423 iteration
# L2 norm converges to threshold value at 5424 iteration
# L2 norm converges to threshold value at 5425 iteration
# L2 norm converges to threshold value at 5426 iteration
# L2 norm converges to threshold value at 5427 iteration
# L2 norm converges to threshold value at 5428 iteration
# L2 norm converges to threshold value at 5429 iteration
# L2 norm converges to threshold value at 5430 iteration
# L2 norm converges to threshold value at 5431 iteration
# L2 norm converges to threshold value at 5432 iteration
# L2 norm converges to threshold value at 5433 iteration
# L2 norm converges to threshold value at 5434 iteration
# L2 norm converges to threshold value at 5435 iteration
# L2 norm converges to threshold value at 5436 iteration
# L2 norm converges to threshold value at 5437 iteration
# L2 norm converges to threshold value at 5438 iteration
# L2 norm converges to threshold value at 5439 iteration
# L2 norm converges to threshold value at 5440 iteration
# L2 norm converges to threshold value at 5441 iteration
# L2 norm converges to threshold value at 5442 iteration
# L2 norm converges to threshold value at 5443 iteration
# L2 norm converges to threshold value at 5444 iteration
# L2 norm converges to threshold value at 5445 iteration
# L2 norm converges to threshold value at 5446 iteration
# L2 norm converges to threshold value at 5447 iteration
# L2 norm converges to threshold value at 5448 iteration
# L2 norm converges to threshold value at 5449 iteration
# L2 norm converges to threshold value at 5450 iteration
# L2 norm converges to threshold value at 5451 iteration
# L2 norm converges to threshold value at 5452 iteration
# L2 norm converges to threshold value at 5453 iteration
# L2 norm converges to threshold value at 5454 iteration
# L2 norm converges to threshold value at 5455 iteration
# L2 norm converges to threshold value at 5456 iteration
# L2 norm converges to threshold value at 5457 iteration
# L2 norm converges to threshold value at 5458 iteration
# L2 norm converges to threshold value at 5459 iteration
# L2 norm converges to threshold value at 5460 iteration
# L2 norm converges to threshold value at 5461 iteration
# L2 norm converges to threshold value at 5462 iteration
# L2 norm converges to threshold value at 5463 iteration
# L2 norm converges to threshold value at 5464 iteration
# L2 norm converges to threshold value at 5465 iteration
# L2 norm converges to threshold value at 5466 iteration
# L2 norm converges to threshold value at 5467 iteration
# L2 norm converges to threshold value at 5468 iteration
# L2 norm converges to threshold value at 5469 iteration
# L2 norm converges to threshold value at 5470 iteration
# L2 norm converges to threshold value at 5471 iteration
# L2 norm converges to threshold value at 5472 iteration
# L2 norm converges to threshold value at 5473 iteration
# L2 norm converges to threshold value at 5474 iteration
# L2 norm converges to threshold value at 5475 iteration
# L2 norm converges to threshold value at 5476 iteration
# L2 norm converges to threshold value at 5477 iteration
# L2 norm converges to threshold value at 5478 iteration
# L2 norm converges to threshold value at 5479 iteration
# L2 norm converges to threshold value at 5480 iteration
# L2 norm converges to threshold value at 5481 iteration
# L2 norm converges to threshold value at 5482 iteration
# L2 norm converges to threshold value at 5483 iteration
# L2 norm converges to threshold value at 5484 iteration
# L2 norm converges to threshold value at 5485 iteration
# L2 norm converges to threshold value at 5486 iteration
# L2 norm converges to threshold value at 5487 iteration
# L2 norm converges to threshold value at 5488 iteration
# L2 norm converges to threshold value at 5489 iteration
# L2 norm converges to threshold value at 5490 iteration
# L2 norm converges to threshold value at 5491 iteration
# L2 norm converges to threshold value at 5492 iteration
# L2 norm converges to threshold value at 5493 iteration
# L2 norm converges to threshold value at 5494 iteration
# L2 norm converges to threshold value at 5495 iteration
# L2 norm converges to threshold value at 5496 iteration
# L2 norm converges to threshold value at 5497 iteration
# L2 norm converges to threshold value at 5498 iteration
# L2 norm converges to threshold value at 5499 iteration
# L2 norm converges to threshold value at 5500 iteration
# L2 norm converges to threshold value at 5501 iteration
# L2 norm converges to threshold value at 5502 iteration
# L2 norm converges to threshold value at 5503 iteration
# L2 norm converges to threshold value at 5504 iteration
# L2 norm converges to threshold value at 5505 iteration
# L2 norm converges to threshold value at 5506 iteration
# L2 norm converges to threshold value at 5507 iteration
# L2 norm converges to threshold value at 5508 iteration
# L2 norm converges to threshold value at 5509 iteration
# L2 norm converges to threshold value at 5510 iteration
# L2 norm converges to threshold value at 5511 iteration
# L2 norm converges to threshold value at 5512 iteration
# L2 norm converges to threshold value at 5513 iteration
# L2 norm converges to threshold value at 5514 iteration
# L2 norm converges to threshold value at 5515 iteration
# L2 norm converges to threshold value at 5516 iteration
# L2 norm converges to threshold value at 5517 iteration
# L2 norm converges to threshold value at 5518 iteration
# L2 norm converges to threshold value at 5519 iteration
# L2 norm converges to threshold value at 5520 iteration
# L2 norm converges to threshold value at 5521 iteration
# L2 norm converges to threshold value at 5522 iteration
# L2 norm converges to threshold value at 5523 iteration
# L2 norm converges to threshold value at 5524 iteration
# L2 norm converges to threshold value at 5525 iteration
# L2 norm converges to threshold value at 5526 iteration
# L2 norm converges to threshold value at 5527 iteration
# L2 norm converges to threshold value at 5528 iteration
# L2 norm converges to threshold value at 5529 iteration
# L2 norm converges to threshold value at 5530 iteration
# L2 norm converges to threshold value at 5531 iteration
# L2 norm converges to threshold value at 5532 iteration
# L2 norm converges to threshold value at 5533 iteration
# L2 norm converges to threshold value at 5534 iteration
# L2 norm converges to threshold value at 5535 iteration
# L2 norm converges to threshold value at 5536 iteration
# L2 norm converges to threshold value at 5537 iteration
# L2 norm converges to threshold value at 5538 iteration
# L2 norm converges to threshold value at 5539 iteration
# L2 norm converges to threshold value at 5540 iteration
# L2 norm converges to threshold value at 5541 iteration
# L2 norm converges to threshold value at 5542 iteration
# L2 norm converges to threshold value at 5543 iteration
# L2 norm converges to threshold value at 5544 iteration
# L2 norm converges to threshold value at 5545 iteration
# L2 norm converges to threshold value at 5546 iteration
# L2 norm converges to threshold value at 5547 iteration
# L2 norm converges to threshold value at 5548 iteration
# L2 norm converges to threshold value at 5549 iteration
# L2 norm converges to threshold value at 5550 iteration
# L2 norm converges to threshold value at 5551 iteration
# L2 norm converges to threshold value at 5552 iteration
# L2 norm converges to threshold value at 5553 iteration
# L2 norm converges to threshold value at 5554 iteration
# L2 norm converges to threshold value at 5555 iteration
# L2 norm converges to threshold value at 5556 iteration
# L2 norm converges to threshold value at 5557 iteration
# L2 norm converges to threshold value at 5558 iteration
# L2 norm converges to threshold value at 5559 iteration
# L2 norm converges to threshold value at 5560 iteration
# L2 norm converges to threshold value at 5561 iteration
# L2 norm converges to threshold value at 5562 iteration
# L2 norm converges to threshold value at 5563 iteration
# L2 norm converges to threshold value at 5564 iteration
# L2 norm converges to threshold value at 5565 iteration
# L2 norm converges to threshold value at 5566 iteration
# L2 norm converges to threshold value at 5567 iteration
# L2 norm converges to threshold value at 5568 iteration
# L2 norm converges to threshold value at 5569 iteration
# L2 norm converges to threshold value at 5570 iteration
# L2 norm converges to threshold value at 5571 iteration
# L2 norm converges to threshold value at 5572 iteration
# L2 norm converges to threshold value at 5573 iteration
# L2 norm converges to threshold value at 5574 iteration
# L2 norm converges to threshold value at 5575 iteration
# L2 norm converges to threshold value at 5576 iteration
# L2 norm converges to threshold value at 5577 iteration
# L2 norm converges to threshold value at 5578 iteration
# L2 norm converges to threshold value at 5579 iteration
# L2 norm converges to threshold value at 5580 iteration
# L2 norm converges to threshold value at 5581 iteration
# L2 norm converges to threshold value at 5582 iteration
# L2 norm converges to threshold value at 5583 iteration
# L2 norm converges to threshold value at 5584 iteration
# L2 norm converges to threshold value at 5585 iteration
# L2 norm converges to threshold value at 5586 iteration
# L2 norm converges to threshold value at 5587 iteration
# L2 norm converges to threshold value at 5588 iteration
# L2 norm converges to threshold value at 5589 iteration
# L2 norm converges to threshold value at 5590 iteration
# L2 norm converges to threshold value at 5591 iteration
# L2 norm converges to threshold value at 5592 iteration
# L2 norm converges to threshold value at 5593 iteration
# L2 norm converges to threshold value at 5594 iteration
# L2 norm converges to threshold value at 5595 iteration
# L2 norm converges to threshold value at 5596 iteration
# L2 norm converges to threshold value at 5597 iteration
# L2 norm converges to threshold value at 5598 iteration
# L2 norm converges to threshold value at 5599 iteration
# L2 norm converges to threshold value at 5600 iteration
# L2 norm converges to threshold value at 5601 iteration
# L2 norm converges to threshold value at 5602 iteration
# L2 norm converges to threshold value at 5603 iteration
# L2 norm converges to threshold value at 5604 iteration
# L2 norm converges to threshold value at 5605 iteration
# L2 norm converges to threshold value at 5606 iteration
# L2 norm converges to threshold value at 5607 iteration
# L2 norm converges to threshold value at 5608 iteration
# L2 norm converges to threshold value at 5609 iteration
# L2 norm converges to threshold value at 5610 iteration
# L2 norm converges to threshold value at 5611 iteration
# L2 norm converges to threshold value at 5612 iteration
# L2 norm converges to threshold value at 5613 iteration
# L2 norm converges to threshold value at 5614 iteration
# L2 norm converges to threshold value at 5615 iteration
# L2 norm converges to threshold value at 5616 iteration
# L2 norm converges to threshold value at 5617 iteration
# L2 norm converges to threshold value at 5618 iteration
# L2 norm converges to threshold value at 5619 iteration
# L2 norm converges to threshold value at 5620 iteration
# L2 norm converges to threshold value at 5621 iteration
# L2 norm converges to threshold value at 5622 iteration
# L2 norm converges to threshold value at 5623 iteration
# L2 norm converges to threshold value at 5624 iteration
# L2 norm converges to threshold value at 5625 iteration
# L2 norm converges to threshold value at 5626 iteration
# L2 norm converges to threshold value at 5627 iteration
# L2 norm converges to threshold value at 5628 iteration
# L2 norm converges to threshold value at 5629 iteration
# L2 norm converges to threshold value at 5630 iteration
# L2 norm converges to threshold value at 5631 iteration
# L2 norm converges to threshold value at 5632 iteration
# L2 norm converges to threshold value at 5633 iteration
# L2 norm converges to threshold value at 5634 iteration
# L2 norm converges to threshold value at 5635 iteration
# L2 norm converges to threshold value at 5636 iteration
# L2 norm converges to threshold value at 5637 iteration
# L2 norm converges to threshold value at 5638 iteration
# L2 norm converges to threshold value at 5639 iteration
# L2 norm converges to threshold value at 5640 iteration
# L2 norm converges to threshold value at 5641 iteration
# L2 norm converges to threshold value at 5642 iteration
# L2 norm converges to threshold value at 5643 iteration
# L2 norm converges to threshold value at 5644 iteration
# L2 norm converges to threshold value at 5645 iteration
# L2 norm converges to threshold value at 5646 iteration
# L2 norm converges to threshold value at 5647 iteration
# L2 norm converges to threshold value at 5648 iteration
# L2 norm converges to threshold value at 5649 iteration
# L2 norm converges to threshold value at 5650 iteration
# L2 norm converges to threshold value at 5651 iteration
# L2 norm converges to threshold value at 5652 iteration
# L2 norm converges to threshold value at 5653 iteration
# L2 norm converges to threshold value at 5654 iteration
# L2 norm converges to threshold value at 5655 iteration
# L2 norm converges to threshold value at 5656 iteration
# L2 norm converges to threshold value at 5657 iteration
# L2 norm converges to threshold value at 5658 iteration
# L2 norm converges to threshold value at 5659 iteration
# L2 norm converges to threshold value at 5660 iteration
# L2 norm converges to threshold value at 5661 iteration
# L2 norm converges to threshold value at 5662 iteration
# L2 norm converges to threshold value at 5663 iteration
# L2 norm converges to threshold value at 5664 iteration
# L2 norm converges to threshold value at 5665 iteration
# L2 norm converges to threshold value at 5666 iteration
# L2 norm converges to threshold value at 5667 iteration
# L2 norm converges to threshold value at 5668 iteration
# L2 norm converges to threshold value at 5669 iteration
# L2 norm converges to threshold value at 5670 iteration
# L2 norm converges to threshold value at 5671 iteration
# L2 norm converges to threshold value at 5672 iteration
# L2 norm converges to threshold value at 5673 iteration
# L2 norm converges to threshold value at 5674 iteration
# L2 norm converges to threshold value at 5675 iteration
# L2 norm converges to threshold value at 5676 iteration
# L2 norm converges to threshold value at 5677 iteration
# L2 norm converges to threshold value at 5678 iteration
# L2 norm converges to threshold value at 5679 iteration
# L2 norm converges to threshold value at 5680 iteration
# L2 norm converges to threshold value at 5681 iteration
# L2 norm converges to threshold value at 5682 iteration
# L2 norm converges to threshold value at 5683 iteration
# L2 norm converges to threshold value at 5684 iteration
# L2 norm converges to threshold value at 5685 iteration
# L2 norm converges to threshold value at 5686 iteration
# L2 norm converges to threshold value at 5687 iteration
# L2 norm converges to threshold value at 5688 iteration
# L2 norm converges to threshold value at 5689 iteration
# L2 norm converges to threshold value at 5690 iteration
# L2 norm converges to threshold value at 5691 iteration
# L2 norm converges to threshold value at 5692 iteration
# L2 norm converges to threshold value at 5693 iteration
# L2 norm converges to threshold value at 5694 iteration
# L2 norm converges to threshold value at 5695 iteration
# L2 norm converges to threshold value at 5696 iteration
# L2 norm converges to threshold value at 5697 iteration
# L2 norm converges to threshold value at 5698 iteration
# L2 norm converges to threshold value at 5699 iteration
# L2 norm converges to threshold value at 5700 iteration
# L2 norm converges to threshold value at 5701 iteration
# L2 norm converges to threshold value at 5702 iteration
# L2 norm converges to threshold value at 5703 iteration
# L2 norm converges to threshold value at 5704 iteration
# L2 norm converges to threshold value at 5705 iteration
# L2 norm converges to threshold value at 5706 iteration
# L2 norm converges to threshold value at 5707 iteration
# L2 norm converges to threshold value at 5708 iteration
# L2 norm converges to threshold value at 5709 iteration
# L2 norm converges to threshold value at 5710 iteration
# L2 norm converges to threshold value at 5711 iteration
# L2 norm converges to threshold value at 5712 iteration
# L2 norm converges to threshold value at 5713 iteration
# L2 norm converges to threshold value at 5714 iteration
# L2 norm converges to threshold value at 5715 iteration
# L2 norm converges to threshold value at 5716 iteration
# L2 norm converges to threshold value at 5717 iteration
# L2 norm converges to threshold value at 5718 iteration
# L2 norm converges to threshold value at 5719 iteration
# L2 norm converges to threshold value at 5720 iteration
# L2 norm converges to threshold value at 5721 iteration
# L2 norm converges to threshold value at 5722 iteration
# L2 norm converges to threshold value at 5723 iteration
# L2 norm converges to threshold value at 5724 iteration
# L2 norm converges to threshold value at 5725 iteration
# L2 norm converges to threshold value at 5726 iteration
# L2 norm converges to threshold value at 5727 iteration
# L2 norm converges to threshold value at 5728 iteration
# L2 norm converges to threshold value at 5729 iteration
# L2 norm converges to threshold value at 5730 iteration
# L2 norm converges to threshold value at 5731 iteration
# L2 norm converges to threshold value at 5732 iteration
# L2 norm converges to threshold value at 5733 iteration
# L2 norm converges to threshold value at 5734 iteration
# L2 norm converges to threshold value at 5735 iteration
# L2 norm converges to threshold value at 5736 iteration
# L2 norm converges to threshold value at 5737 iteration
# L2 norm converges to threshold value at 5738 iteration
# L2 norm converges to threshold value at 5739 iteration
# L2 norm converges to threshold value at 5740 iteration
# L2 norm converges to threshold value at 5741 iteration
# L2 norm converges to threshold value at 5742 iteration
# L2 norm converges to threshold value at 5743 iteration
# L2 norm converges to threshold value at 5744 iteration
# L2 norm converges to threshold value at 5745 iteration
# L2 norm converges to threshold value at 5746 iteration
# L2 norm converges to threshold value at 5747 iteration
# L2 norm converges to threshold value at 5748 iteration
# L2 norm converges to threshold value at 5749 iteration
# L2 norm converges to threshold value at 5750 iteration
# L2 norm converges to threshold value at 5751 iteration
# L2 norm converges to threshold value at 5752 iteration
# L2 norm converges to threshold value at 5753 iteration
# L2 norm converges to threshold value at 5754 iteration
# L2 norm converges to threshold value at 5755 iteration
# L2 norm converges to threshold value at 5756 iteration
# L2 norm converges to threshold value at 5757 iteration
# L2 norm converges to threshold value at 5758 iteration
# L2 norm converges to threshold value at 5759 iteration
# L2 norm converges to threshold value at 5760 iteration
# L2 norm converges to threshold value at 5761 iteration
# L2 norm converges to threshold value at 5762 iteration
# L2 norm converges to threshold value at 5763 iteration
# L2 norm converges to threshold value at 5764 iteration
# L2 norm converges to threshold value at 5765 iteration
# L2 norm converges to threshold value at 5766 iteration
# L2 norm converges to threshold value at 5767 iteration
# L2 norm converges to threshold value at 5768 iteration
# L2 norm converges to threshold value at 5769 iteration
# L2 norm converges to threshold value at 5770 iteration
# L2 norm converges to threshold value at 5771 iteration
# L2 norm converges to threshold value at 5772 iteration
# L2 norm converges to threshold value at 5773 iteration
# L2 norm converges to threshold value at 5774 iteration
# L2 norm converges to threshold value at 5775 iteration
# L2 norm converges to threshold value at 5776 iteration
# L2 norm converges to threshold value at 5777 iteration
# L2 norm converges to threshold value at 5778 iteration
# L2 norm converges to threshold value at 5779 iteration
# L2 norm converges to threshold value at 5780 iteration
# L2 norm converges to threshold value at 5781 iteration
# L2 norm converges to threshold value at 5782 iteration
# L2 norm converges to threshold value at 5783 iteration
# L2 norm converges to threshold value at 5784 iteration
# L2 norm converges to threshold value at 5785 iteration
# L2 norm converges to threshold value at 5786 iteration
# L2 norm converges to threshold value at 5787 iteration
# L2 norm converges to threshold value at 5788 iteration
# L2 norm converges to threshold value at 5789 iteration
# L2 norm converges to threshold value at 5790 iteration
# L2 norm converges to threshold value at 5791 iteration
# L2 norm converges to threshold value at 5792 iteration
# L2 norm converges to threshold value at 5793 iteration
# L2 norm converges to threshold value at 5794 iteration
# L2 norm converges to threshold value at 5795 iteration
# L2 norm converges to threshold value at 5796 iteration
# L2 norm converges to threshold value at 5797 iteration
# L2 norm converges to threshold value at 5798 iteration
# L2 norm converges to threshold value at 5799 iteration
# L2 norm converges to threshold value at 5800 iteration
# L2 norm converges to threshold value at 5801 iteration
# L2 norm converges to threshold value at 5802 iteration
# L2 norm converges to threshold value at 5803 iteration
# L2 norm converges to threshold value at 5804 iteration
# L2 norm converges to threshold value at 5805 iteration
# L2 norm converges to threshold value at 5806 iteration
# L2 norm converges to threshold value at 5807 iteration
# L2 norm converges to threshold value at 5808 iteration
# L2 norm converges to threshold value at 5809 iteration
# L2 norm converges to threshold value at 5810 iteration
# L2 norm converges to threshold value at 5811 iteration
# L2 norm converges to threshold value at 5812 iteration
# L2 norm converges to threshold value at 5813 iteration
# L2 norm converges to threshold value at 5814 iteration
# L2 norm converges to threshold value at 5815 iteration
# L2 norm converges to threshold value at 5816 iteration
# L2 norm converges to threshold value at 5817 iteration
# L2 norm converges to threshold value at 5818 iteration
# L2 norm converges to threshold value at 5819 iteration
# L2 norm converges to threshold value at 5820 iteration
# L2 norm converges to threshold value at 5821 iteration
# L2 norm converges to threshold value at 5822 iteration
# L2 norm converges to threshold value at 5823 iteration
# L2 norm converges to threshold value at 5824 iteration
# L2 norm converges to threshold value at 5825 iteration
# L2 norm converges to threshold value at 5826 iteration
# L2 norm converges to threshold value at 5827 iteration
# L2 norm converges to threshold value at 5828 iteration
# L2 norm converges to threshold value at 5829 iteration
# L2 norm converges to threshold value at 5830 iteration
# L2 norm converges to threshold value at 5831 iteration
# L2 norm converges to threshold value at 5832 iteration
# L2 norm converges to threshold value at 5833 iteration
# L2 norm converges to threshold value at 5834 iteration
# L2 norm converges to threshold value at 5835 iteration
# L2 norm converges to threshold value at 5836 iteration
# L2 norm converges to threshold value at 5837 iteration
# L2 norm converges to threshold value at 5838 iteration
# L2 norm converges to threshold value at 5839 iteration
# L2 norm converges to threshold value at 5840 iteration
# L2 norm converges to threshold value at 5841 iteration
# L2 norm converges to threshold value at 5842 iteration
# L2 norm converges to threshold value at 5843 iteration
# L2 norm converges to threshold value at 5844 iteration
# L2 norm converges to threshold value at 5845 iteration
# L2 norm converges to threshold value at 5846 iteration
# L2 norm converges to threshold value at 5847 iteration
# L2 norm converges to threshold value at 5848 iteration
# L2 norm converges to threshold value at 5849 iteration
# L2 norm converges to threshold value at 5850 iteration
# L2 norm converges to threshold value at 5851 iteration
# L2 norm converges to threshold value at 5852 iteration
# L2 norm converges to threshold value at 5853 iteration
# L2 norm converges to threshold value at 5854 iteration
# L2 norm converges to threshold value at 5855 iteration
# L2 norm converges to threshold value at 5856 iteration
# L2 norm converges to threshold value at 5857 iteration
# L2 norm converges to threshold value at 5858 iteration
# L2 norm converges to threshold value at 5859 iteration
# L2 norm converges to threshold value at 5860 iteration
# L2 norm converges to threshold value at 5861 iteration
# L2 norm converges to threshold value at 5862 iteration
# L2 norm converges to threshold value at 5863 iteration
# L2 norm converges to threshold value at 5864 iteration
# L2 norm converges to threshold value at 5865 iteration
# L2 norm converges to threshold value at 5866 iteration
# L2 norm converges to threshold value at 5867 iteration
# L2 norm converges to threshold value at 5868 iteration
# L2 norm converges to threshold value at 5869 iteration
# L2 norm converges to threshold value at 5870 iteration
# L2 norm converges to threshold value at 5871 iteration
# L2 norm converges to threshold value at 5872 iteration
# ...
# L2 norm converges to threshold value at 9712 iteration
# L2 norm converges to threshold value at 9713 iteration
# L2 norm converges to threshold value at 9714 iteration
# L2 norm converges to threshold value at 9715 iteration
# L2 norm converges to threshold value at 9716 iteration
# L2 norm converges to threshold value at 9717 iteration
# L2 norm converges to threshold value at 9718 iteration
# L2 norm converges to threshold value at 9719 iteration
# L2 norm converges to threshold value at 9720 iteration
# L2 norm converges to threshold value at 9721 iteration
# L2 norm converges to threshold value at 9722 iteration
# L2 norm converges to threshold value at 9723 iteration
# L2 norm converges to threshold value at 9724 iteration
# L2 norm converges to threshold value at 9725 iteration
# L2 norm converges to threshold value at 9726 iteration
# L2 norm converges to threshold value at 9727 iteration
# L2 norm converges to threshold value at 9728 iteration
# L2 norm converges to threshold value at 9729 iteration
# L2 norm converges to threshold value at 9730 iteration
# L2 norm converges to threshold value at 9731 iteration
# L2 norm converges to threshold value at 9732 iteration
# L2 norm converges to threshold value at 9733 iteration
# L2 norm converges to threshold value at 9734 iteration
# L2 norm converges to threshold value at 9735 iteration
# L2 norm converges to threshold value at 9736 iteration
# L2 norm converges to threshold value at 9737 iteration
# L2 norm converges to threshold value at 9738 iteration
# L2 norm converges to threshold value at 9739 iteration
# L2 norm converges to threshold value at 9740 iteration
# L2 norm converges to threshold value at 9741 iteration
# L2 norm converges to threshold value at 9742 iteration
# L2 norm converges to threshold value at 9743 iteration
# L2 norm converges to threshold value at 9744 iteration
# L2 norm converges to threshold value at 9745 iteration
# L2 norm converges to threshold value at 9746 iteration
# L2 norm converges to threshold value at 9747 iteration
# L2 norm converges to threshold value at 9748 iteration
# L2 norm converges to threshold value at 9749 iteration
# L2 norm converges to threshold value at 9750 iteration
# L2 norm converges to threshold value at 9751 iteration
# L2 norm converges to threshold value at 9752 iteration
# L2 norm converges to threshold value at 9753 iteration
# L2 norm converges to threshold value at 9754 iteration
# L2 norm converges to threshold value at 9755 iteration
# L2 norm converges to threshold value at 9756 iteration
# L2 norm converges to threshold value at 9757 iteration
# L2 norm converges to threshold value at 9758 iteration
# L2 norm converges to threshold value at 9759 iteration
# L2 norm converges to threshold value at 9760 iteration
# L2 norm converges to threshold value at 9761 iteration
# L2 norm converges to threshold value at 9762 iteration
# L2 norm converges to threshold value at 9763 iteration
# L2 norm converges to threshold value at 9764 iteration
# L2 norm converges to threshold value at 9765 iteration
# L2 norm converges to threshold value at 9766 iteration
# L2 norm converges to threshold value at 9767 iteration
# L2 norm converges to threshold value at 9768 iteration
# L2 norm converges to threshold value at 9769 iteration
# L2 norm converges to threshold value at 9770 iteration
# L2 norm converges to threshold value at 9771 iteration
# L2 norm converges to threshold value at 9772 iteration
# L2 norm converges to threshold value at 9773 iteration
# L2 norm converges to threshold value at 9774 iteration
# L2 norm converges to threshold value at 9775 iteration
# L2 norm converges to threshold value at 9776 iteration
# L2 norm converges to threshold value at 9777 iteration
# L2 norm converges to threshold value at 9778 iteration
# L2 norm converges to threshold value at 9779 iteration
# L2 norm converges to threshold value at 9780 iteration
# L2 norm converges to threshold value at 9781 iteration
# L2 norm converges to threshold value at 9782 iteration
# L2 norm converges to threshold value at 9783 iteration
# L2 norm converges to threshold value at 9784 iteration
# L2 norm converges to threshold value at 9785 iteration
# L2 norm converges to threshold value at 9786 iteration
# L2 norm converges to threshold value at 9787 iteration
# L2 norm converges to threshold value at 9788 iteration
# L2 norm converges to threshold value at 9789 iteration
# L2 norm converges to threshold value at 9790 iteration
# L2 norm converges to threshold value at 9791 iteration
# L2 norm converges to threshold value at 9792 iteration
# L2 norm converges to threshold value at 9793 iteration
# L2 norm converges to threshold value at 9794 iteration
# L2 norm converges to threshold value at 9795 iteration
# L2 norm converges to threshold value at 9796 iteration
# L2 norm converges to threshold value at 9797 iteration
# L2 norm converges to threshold value at 9798 iteration
# L2 norm converges to threshold value at 9799 iteration
# L2 norm converges to threshold value at 9800 iteration
# L2 norm converges to threshold value at 9801 iteration
# L2 norm converges to threshold value at 9802 iteration
# L2 norm converges to threshold value at 9803 iteration
# L2 norm converges to threshold value at 9804 iteration
# L2 norm converges to threshold value at 9805 iteration
# L2 norm converges to threshold value at 9806 iteration
# L2 norm converges to threshold value at 9807 iteration
# L2 norm converges to threshold value at 9808 iteration
# L2 norm converges to threshold value at 9809 iteration
# L2 norm converges to threshold value at 9810 iteration
# L2 norm converges to threshold value at 9811 iteration
# L2 norm converges to threshold value at 9812 iteration
# L2 norm converges to threshold value at 9813 iteration
# L2 norm converges to threshold value at 9814 iteration
# L2 norm converges to threshold value at 9815 iteration
# L2 norm converges to threshold value at 9816 iteration
# L2 norm converges to threshold value at 9817 iteration
# L2 norm converges to threshold value at 9818 iteration
# L2 norm converges to threshold value at 9819 iteration
# L2 norm converges to threshold value at 9820 iteration
# L2 norm converges to threshold value at 9821 iteration
# L2 norm converges to threshold value at 9822 iteration
# L2 norm converges to threshold value at 9823 iteration
# L2 norm converges to threshold value at 9824 iteration
# L2 norm converges to threshold value at 9825 iteration
# L2 norm converges to threshold value at 9826 iteration
# L2 norm converges to threshold value at 9827 iteration
# L2 norm converges to threshold value at 9828 iteration
# L2 norm converges to threshold value at 9829 iteration
# L2 norm converges to threshold value at 9830 iteration
# L2 norm converges to threshold value at 9831 iteration
# L2 norm converges to threshold value at 9832 iteration
# L2 norm converges to threshold value at 9833 iteration
# L2 norm converges to threshold value at 9834 iteration
# L2 norm converges to threshold value at 9835 iteration
# L2 norm converges to threshold value at 9836 iteration
# L2 norm converges to threshold value at 9837 iteration
# L2 norm converges to threshold value at 9838 iteration
# L2 norm converges to threshold value at 9839 iteration
# L2 norm converges to threshold value at 9840 iteration
# L2 norm converges to threshold value at 9841 iteration
# L2 norm converges to threshold value at 9842 iteration
# L2 norm converges to threshold value at 9843 iteration
# L2 norm converges to threshold value at 9844 iteration
# L2 norm converges to threshold value at 9845 iteration
# L2 norm converges to threshold value at 9846 iteration
# L2 norm converges to threshold value at 9847 iteration
# L2 norm converges to threshold value at 9848 iteration
# L2 norm converges to threshold value at 9849 iteration
# L2 norm converges to threshold value at 9850 iteration
# L2 norm converges to threshold value at 9851 iteration
# L2 norm converges to threshold value at 9852 iteration
# L2 norm converges to threshold value at 9853 iteration
# L2 norm converges to threshold value at 9854 iteration
# L2 norm converges to threshold value at 9855 iteration
# L2 norm converges to threshold value at 9856 iteration
# L2 norm converges to threshold value at 9857 iteration
# L2 norm converges to threshold value at 9858 iteration
# L2 norm converges to threshold value at 9859 iteration
# L2 norm converges to threshold value at 9860 iteration
# L2 norm converges to threshold value at 9861 iteration
# L2 norm converges to threshold value at 9862 iteration
# L2 norm converges to threshold value at 9863 iteration
# L2 norm converges to threshold value at 9864 iteration
# L2 norm converges to threshold value at 9865 iteration
# L2 norm converges to threshold value at 9866 iteration
# L2 norm converges to threshold value at 9867 iteration
# L2 norm converges to threshold value at 9868 iteration
# L2 norm converges to threshold value at 9869 iteration
# L2 norm converges to threshold value at 9870 iteration
# L2 norm converges to threshold value at 9871 iteration
# L2 norm converges to threshold value at 9872 iteration
# L2 norm converges to threshold value at 9873 iteration
# L2 norm converges to threshold value at 9874 iteration
# L2 norm converges to threshold value at 9875 iteration
# L2 norm converges to threshold value at 9876 iteration
# L2 norm converges to threshold value at 9877 iteration
# L2 norm converges to threshold value at 9878 iteration
# L2 norm converges to threshold value at 9879 iteration
# L2 norm converges to threshold value at 9880 iteration
# L2 norm converges to threshold value at 9881 iteration
# L2 norm converges to threshold value at 9882 iteration
# L2 norm converges to threshold value at 9883 iteration
# L2 norm converges to threshold value at 9884 iteration
# L2 norm converges to threshold value at 9885 iteration
# L2 norm converges to threshold value at 9886 iteration
# L2 norm converges to threshold value at 9887 iteration
# L2 norm converges to threshold value at 9888 iteration
# L2 norm converges to threshold value at 9889 iteration
# L2 norm converges to threshold value at 9890 iteration
# L2 norm converges to threshold value at 9891 iteration
# L2 norm converges to threshold value at 9892 iteration
# L2 norm converges to threshold value at 9893 iteration
# L2 norm converges to threshold value at 9894 iteration
# L2 norm converges to threshold value at 9895 iteration
# L2 norm converges to threshold value at 9896 iteration
# L2 norm converges to threshold value at 9897 iteration
# L2 norm converges to threshold value at 9898 iteration
# L2 norm converges to threshold value at 9899 iteration
# L2 norm converges to threshold value at 9900 iteration
# L2 norm converges to threshold value at 9901 iteration
# L2 norm converges to threshold value at 9902 iteration
# L2 norm converges to threshold value at 9903 iteration
# L2 norm converges to threshold value at 9904 iteration
# L2 norm converges to threshold value at 9905 iteration
# L2 norm converges to threshold value at 9906 iteration
# L2 norm converges to threshold value at 9907 iteration
# L2 norm converges to threshold value at 9908 iteration
# L2 norm converges to threshold value at 9909 iteration
# L2 norm converges to threshold value at 9910 iteration
# L2 norm converges to threshold value at 9911 iteration
# L2 norm converges to threshold value at 9912 iteration
# L2 norm converges to threshold value at 9913 iteration
# L2 norm converges to threshold value at 9914 iteration
# L2 norm converges to threshold value at 9915 iteration
# L2 norm converges to threshold value at 9916 iteration
# L2 norm converges to threshold value at 9917 iteration
# L2 norm converges to threshold value at 9918 iteration
# L2 norm converges to threshold value at 9919 iteration
# L2 norm converges to threshold value at 9920 iteration
# L2 norm converges to threshold value at 9921 iteration
# L2 norm converges to threshold value at 9922 iteration
# L2 norm converges to threshold value at 9923 iteration
# L2 norm converges to threshold value at 9924 iteration
# L2 norm converges to threshold value at 9925 iteration
# L2 norm converges to threshold value at 9926 iteration
# L2 norm converges to threshold value at 9927 iteration
# L2 norm converges to threshold value at 9928 iteration
# L2 norm converges to threshold value at 9929 iteration
# L2 norm converges to threshold value at 9930 iteration
# L2 norm converges to threshold value at 9931 iteration
# L2 norm converges to threshold value at 9932 iteration
# L2 norm converges to threshold value at 9933 iteration
# L2 norm converges to threshold value at 9934 iteration
# L2 norm converges to threshold value at 9935 iteration
# L2 norm converges to threshold value at 9936 iteration
# L2 norm converges to threshold value at 9937 iteration
# L2 norm converges to threshold value at 9938 iteration
# L2 norm converges to threshold value at 9939 iteration
# L2 norm converges to threshold value at 9940 iteration
# L2 norm converges to threshold value at 9941 iteration
# L2 norm converges to threshold value at 9942 iteration
# L2 norm converges to threshold value at 9943 iteration
# L2 norm converges to threshold value at 9944 iteration
# L2 norm converges to threshold value at 9945 iteration
# L2 norm converges to threshold value at 9946 iteration
# L2 norm converges to threshold value at 9947 iteration
# L2 norm converges to threshold value at 9948 iteration
# L2 norm converges to threshold value at 9949 iteration
# L2 norm converges to threshold value at 9950 iteration
# L2 norm converges to threshold value at 9951 iteration
# L2 norm converges to threshold value at 9952 iteration
# L2 norm converges to threshold value at 9953 iteration
# L2 norm converges to threshold value at 9954 iteration
# L2 norm converges to threshold value at 9955 iteration
# L2 norm converges to threshold value at 9956 iteration
# L2 norm converges to threshold value at 9957 iteration
# L2 norm converges to threshold value at 9958 iteration
# L2 norm converges to threshold value at 9959 iteration
# L2 norm converges to threshold value at 9960 iteration
# L2 norm converges to threshold value at 9961 iteration
# L2 norm converges to threshold value at 9962 iteration
# L2 norm converges to threshold value at 9963 iteration
# L2 norm converges to threshold value at 9964 iteration
# L2 norm converges to threshold value at 9965 iteration
# L2 norm converges to threshold value at 9966 iteration
# L2 norm converges to threshold value at 9967 iteration
# L2 norm converges to threshold value at 9968 iteration
# L2 norm converges to threshold value at 9969 iteration
# L2 norm converges to threshold value at 9970 iteration
# L2 norm converges to threshold value at 9971 iteration
# L2 norm converges to threshold value at 9972 iteration
# L2 norm converges to threshold value at 9973 iteration
# L2 norm converges to threshold value at 9974 iteration
# L2 norm converges to threshold value at 9975 iteration
# L2 norm converges to threshold value at 9976 iteration
# L2 norm converges to threshold value at 9977 iteration
# L2 norm converges to threshold value at 9978 iteration
# L2 norm converges to threshold value at 9979 iteration
# L2 norm converges to threshold value at 9980 iteration
# L2 norm converges to threshold value at 9981 iteration
# L2 norm converges to threshold value at 9982 iteration
# L2 norm converges to threshold value at 9983 iteration
# L2 norm converges to threshold value at 9984 iteration
# L2 norm converges to threshold value at 9985 iteration
# L2 norm converges to threshold value at 9986 iteration
# L2 norm converges to threshold value at 9987 iteration
# L2 norm converges to threshold value at 9988 iteration
# L2 norm converges to threshold value at 9989 iteration
# L2 norm converges to threshold value at 9990 iteration
# L2 norm converges to threshold value at 9991 iteration
# L2 norm converges to threshold value at 9992 iteration
# L2 norm converges to threshold value at 9993 iteration
# L2 norm converges to threshold value at 9994 iteration
# L2 norm converges to threshold value at 9995 iteration
# L2 norm converges to threshold value at 9996 iteration
# L2 norm converges to threshold value at 9997 iteration
# L2 norm converges to threshold value at 9998 iteration
# L2 norm converges to threshold value at 9999 iteration
# L2 norm converges to threshold value at 10000 iteration
# Estimated states: [12.32981136 12.83370395  1.66620626  1.42889563]

# %%
# Initialize variables
dt = 0.1
num_tanks = 4
num_measurements = len(z_true)
# A = np.eye(num_tanks)  # Transition matrix
# B = np.eye(num_tanks)  # Input matrix
# u = np.zeros((num_tanks, num_measurements))  # Input vector
X_post = np.ones((num_tanks, 1))  # Initial state estimate
P_post = 1e5 * np.eye(num_tanks)  # Initial error covariance
Q = 0.1 * np.eye(num_tanks)  # Process noise covariance
R = 100 * np.eye(2)  # Measurement noise covariance

# Define the measurement matrix
# H = np.eye(num_tanks)
kc=0.5
H=[[kc,0,0,0],[0,kc,0,0]]
H=np.array(H)
# Initialize lists to store values for plotting
X_post_list = []
P_post_list = []
P_pri_list = []
Kalman_gain_list = []

x_post_old = np.zeros(num_measurements)
# Kalman filter loop
for k in range(num_measurements):
    # Prediction step
    X_pri = np.dot(A, X_post) + np.dot(B, u[:].reshape(-1, 1))
    P_pri = np.dot(np.dot(A, P_post), A.T) + Q

    # Update step
    K = np.dot(np.dot(P_pri, H.T), np.linalg.inv(np.dot(np.dot(H, P_pri), H.T) + R))
    Z_est = np.dot(H, X_pri)
    E = z_true[k,:2] - Z_est.flatten()
    X_post = X_pri + np.dot(K, E.reshape(-1, 1))
    P_post = P_pri - np.dot(np.dot(K, H), P_pri)

    # Append values to the lists
    X_post_list.append(X_post.flatten())
    P_post_list.append(np.trace(P_post))
    P_pri_list.append(np.trace(P_pri))
    Kalman_gain_list.append(np.trace(K))


    # Calculate the L2 norm

    l2_norm = np.linalg.norm(x_post_old - X_post)
    x_post_old = X_post

    # Check if the L2 norm is less than or equal to the threshold
    threshold = 5e-3
    if l2_norm <= threshold:
        print(f"L2 norm converges to threshold value at {k} iteration")
        break


    # Stop condition: X_post - X_pri approx = 0
    if np.allclose(X_post, X_pri):
        break

# Final estimated states
estimated_states = X_post.flatten()
print("Estimated states:", estimated_states)
# Out:
# L2 norm converges to threshold value at 4 iteration
# Estimated states: [0.25760037 0.19561352 0.13777148 0.09062095]

# %%
from pandas.core.algorithms import validate_indices
# Initialize variables
dt = 0.1
num_tanks = 4
num_measurements = len(z_true)
# A = np.eye(num_tanks)  # Transition matrix
# B = np.eye(num_tanks)  # Input matrix
# u = np.zeros((num_tanks, num_measurements))  # Input vector
X_post_0 = z_true[1,:4].reshape(-1,1)  # Initial state estimate
P_post_0 = 1e5 * np.eye(num_tanks)  # Initial error covariance
Q = 0.1 * np.eye(num_tanks)  # Process noise covariance
R = 100 * np.eye(2)  # Measurement noise covariance

# Initial state of the tank heights
h0 = np.array([[12.4, 12.7, 1.8, 1.4]]).T

# Define the measurement matrix
kc=0.5
H=[[kc,0,0,0],[0,kc,0,0]]
H=np.array(H)

# Initialize lists to store values for plotting
X_post_list = []
X_pri_list=[]
P_post_list = []
P_pri_list = []
Kalman_gain_list = []
Innovation_store_list=[]
Residue_store_list=[]

# x_post_old = np.zeros(num_measurements)
# Kalman filter loop
for k in range(num_measurements):
  # Voltage obtained using H and true height measurements
  V_in=np.dot(H,z_true[k,:4].reshape(-1,1))

  # Prediction steps
  #Height prior calculation as mentioned in paper
  X_pri = (np.dot(A, (X_post_0-h0)) + np.dot(B, (V_in-u)))*dt
  #Getting actual height by adding previous iteration height
  X_pri+=h0

  #Updating h0
  h0 = z_true[k,:4].reshape(-1,1)

  #Now calculating process noise covariance matrix
  P_pri = (np.dot(np.dot(A, P_post_0), A.T) + Q)*dt**2

  # Update step starts
  #Calculating Kalman gain
  K = np.dot(np.dot(P_pri, H.T), np.linalg.inv(np.dot(np.dot(H, P_pri), H.T) + R))

  #Estimating the output voltage at each timestamp
  V_out=np.dot(H,z_true[k,:4].reshape(-1,1))
  Z_est = np.dot(H, X_pri)

  #Calculating error between true and predicted voltage
  E = V_out - Z_est

  #Kalman height update step
  X_post = X_pri + np.dot(K, E)
  #Kalman process noise covariance updation
  P_post = P_pri - np.dot(np.dot(K, H), P_pri)

  # Append values to the lists
  X_post_list.append(X_post.flatten())
  P_post_list.append(np.trace(P_post))
  X_pri_list.append(X_pri.flatten())
  P_pri_list.append(np.trace(P_pri))
  Kalman_gain_list.append(np.trace(K))
  Innovation_store_list.append(E.flatten())
  Residue_store_list.append((z_true[k, :2].reshape(-1,1) - H.dot(X_post)).tolist())

  X_post_0=X_post
  P_post_0=P_post

  # Calculate the L2 norm

  l2_norm = np.linalg.norm(X_pri - X_post)
  # Check if the L2 norm is less than or equal to the threshold
  threshold = 5e-3
  if l2_norm <= threshold:
    print(f"L2 norm converges to threshold value at {k} iteration with threshhold {l2_norm}")
  else:
    print(f'L2 norm is {l2_norm} and still Kalman filter cant achieve threshhold value error')



  # # Stop condition: X_post - X_pri approx = 0
  # if np.allclose(X_post, X_pri):
  #     break

# Final estimated states
estimated_states = X_post.flatten()
print("Estimated states are:", estimated_states)
# Out:
# Streaming output truncated to the last 5000 lines.
# L2 norm converges to threshold value at 5002 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5003 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5004 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5005 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5006 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5007 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5008 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5009 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5010 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5011 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5012 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5013 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5014 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5015 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5016 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5017 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5018 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5019 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5020 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5021 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5022 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5023 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5024 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5025 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5026 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5027 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5028 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5029 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5030 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5031 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5032 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5033 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5034 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5035 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5036 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5037 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5038 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5039 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5040 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5041 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5042 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5043 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5044 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5045 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5046 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5047 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5048 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5049 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5050 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5051 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5052 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5053 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5054 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5055 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5056 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5057 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5058 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5059 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5060 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5061 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5062 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5063 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5064 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5065 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5066 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5067 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5068 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5069 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5070 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5071 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5072 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5073 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5074 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5075 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5076 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5077 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5078 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5079 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5080 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5081 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5082 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5083 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5084 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5085 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5086 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5087 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5088 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5089 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5090 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5091 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5092 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5093 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5094 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5095 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5096 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5097 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5098 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5099 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5100 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5101 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5102 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5103 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5104 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5105 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5106 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5107 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5108 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5109 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5110 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5111 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5112 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5113 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5114 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5115 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5116 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5117 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5118 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5119 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5120 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5121 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5122 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5123 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5124 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5125 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5126 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5127 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5128 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5129 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5130 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5131 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5132 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5133 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5134 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5135 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5136 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5137 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5138 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5139 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5140 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5141 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5142 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5143 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5144 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5145 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5146 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5147 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5148 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5149 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5150 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5151 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5152 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5153 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5154 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5155 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5156 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5157 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5158 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5159 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5160 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5161 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5162 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5163 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5164 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5165 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5166 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5167 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5168 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5169 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5170 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5171 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5172 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5173 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5174 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5175 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5176 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5177 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5178 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5179 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5180 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5181 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5182 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5183 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5184 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5185 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5186 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5187 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5188 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5189 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5190 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5191 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5192 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5193 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5194 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5195 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5196 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5197 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5198 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5199 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5200 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5201 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5202 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5203 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5204 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5205 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5206 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5207 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5208 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5209 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5210 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5211 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5212 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5213 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5214 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5215 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5216 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5217 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5218 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5219 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5220 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5221 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5222 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5223 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5224 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5225 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5226 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5227 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5228 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5229 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5230 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5231 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5232 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5233 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5234 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5235 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5236 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5237 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5238 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5239 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5240 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5241 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5242 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5243 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5244 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5245 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5246 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5247 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5248 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5249 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5250 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5251 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5252 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5253 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5254 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5255 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5256 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5257 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5258 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5259 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5260 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5261 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5262 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5263 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5264 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5265 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5266 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5267 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5268 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5269 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5270 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5271 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5272 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5273 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5274 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5275 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5276 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5277 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5278 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5279 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5280 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5281 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5282 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5283 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5284 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5285 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5286 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5287 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5288 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5289 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5290 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5291 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5292 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5293 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5294 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5295 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5296 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5297 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5298 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5299 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5300 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5301 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5302 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5303 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5304 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5305 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5306 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5307 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5308 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5309 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5310 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5311 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5312 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5313 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5314 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5315 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5316 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5317 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5318 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5319 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5320 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5321 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5322 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5323 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5324 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5325 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5326 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5327 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5328 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5329 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5330 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5331 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5332 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5333 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5334 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5335 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5336 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5337 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5338 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5339 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5340 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5341 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5342 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5343 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5344 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5345 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5346 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5347 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5348 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5349 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5350 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5351 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5352 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5353 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5354 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5355 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5356 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5357 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5358 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5359 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5360 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5361 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5362 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5363 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5364 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5365 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5366 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5367 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5368 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5369 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5370 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5371 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5372 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5373 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5374 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5375 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5376 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5377 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5378 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5379 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5380 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5381 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5382 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5383 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5384 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5385 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5386 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5387 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5388 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5389 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5390 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5391 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5392 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5393 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5394 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5395 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5396 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5397 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5398 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5399 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5400 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5401 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5402 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5403 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5404 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5405 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5406 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5407 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5408 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5409 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5410 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5411 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5412 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5413 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5414 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5415 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5416 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5417 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5418 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5419 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5420 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5421 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5422 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5423 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5424 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5425 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5426 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5427 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5428 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5429 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5430 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5431 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5432 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5433 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5434 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5435 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5436 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5437 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5438 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5439 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5440 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5441 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5442 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5443 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5444 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5445 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5446 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5447 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5448 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5449 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5450 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5451 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5452 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5453 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5454 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5455 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5456 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5457 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5458 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5459 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5460 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5461 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5462 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5463 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5464 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5465 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5466 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5467 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5468 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5469 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5470 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5471 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5472 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5473 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5474 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5475 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5476 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5477 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5478 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5479 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5480 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5481 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5482 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5483 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5484 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5485 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5486 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5487 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5488 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5489 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5490 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5491 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5492 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5493 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5494 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5495 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5496 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5497 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5498 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5499 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5500 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5501 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5502 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5503 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5504 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5505 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5506 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5507 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5508 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5509 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5510 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5511 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5512 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5513 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5514 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5515 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 5516 iteration with threshhold 8.423284864743751e-08
# ...
# L2 norm converges to threshold value at 9830 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9831 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9832 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9833 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9834 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9835 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9836 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9837 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9838 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9839 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9840 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9841 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9842 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9843 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9844 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9845 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9846 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9847 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9848 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9849 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9850 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9851 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9852 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9853 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9854 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9855 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9856 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9857 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9858 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9859 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9860 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9861 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9862 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9863 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9864 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9865 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9866 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9867 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9868 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9869 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9870 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9871 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9872 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9873 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9874 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9875 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9876 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9877 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9878 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9879 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9880 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9881 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9882 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9883 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9884 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9885 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9886 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9887 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9888 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9889 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9890 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9891 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9892 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9893 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9894 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9895 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9896 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9897 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9898 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9899 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9900 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9901 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9902 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9903 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9904 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9905 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9906 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9907 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9908 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9909 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9910 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9911 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9912 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9913 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9914 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9915 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9916 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9917 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9918 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9919 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9920 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9921 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9922 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9923 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9924 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9925 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9926 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9927 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9928 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9929 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9930 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9931 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9932 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9933 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9934 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9935 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9936 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9937 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9938 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9939 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9940 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9941 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9942 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9943 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9944 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9945 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9946 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9947 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9948 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9949 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9950 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9951 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9952 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9953 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9954 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9955 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9956 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9957 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9958 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9959 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9960 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9961 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9962 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9963 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9964 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9965 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9966 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9967 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9968 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9969 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9970 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9971 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9972 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9973 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9974 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9975 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9976 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9977 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9978 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9979 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9980 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9981 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9982 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9983 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9984 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9985 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9986 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9987 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9988 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9989 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9990 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9991 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9992 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9993 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9994 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9995 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9996 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9997 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9998 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 9999 iteration with threshhold 8.423284864743751e-08
# L2 norm converges to threshold value at 10000 iteration with threshhold 8.423284864743751e-08
# Estimated states are: [12.2890631  12.8044706   1.6501046   1.41878831]

# %%
X_pri.shape
# Out:
# (4, 1)

# %%
X_post.shape
# Out:
# (4, 1)

# %%
K.shape
# Out:
# (4, 2)

# %%
E.shape
# Out:
# (2, 1)

# %%
time_steps=np.arange(0,10001)
time_steps
# Out:
# array([    0,     1,     2, ...,  9998,  9999, 10000])

# %%
def Plot_graphs(tank_num, time_steps, original_data, Kalman_results, measurements, tank_name, marker):
    """

    Parameters of function:
        tank_num (int): The subplot number for the current tank.
        time_steps (numpy.ndarray): Array of time steps.
        original_data (numpy.ndarray): Array of original tank data.
        Kalman_results (numpy.ndarray): Array of filter results for the current tank.
        measurements (numpy.ndarray): Array of tank measurements for the current tank.
        tank_name (str): Name of the current tank.
        marker (str): Marking the tank wise plot

    Returns:
        None
    """
    # Create a subplot for the current tank
    plt.subplot(1, 4, tank_num)
    # Plot the original tank data
    plt.plot(time_steps, original_data, label='Original Data', color='blue')
    # Plot the filter results
    plt.plot(time_steps, Kalman_results, label='Filter Results', color='red')
    # Plot the tank measurements
    plt.scatter(time_steps, measurements, label='Measurements', color='green', marker=marker, s = 30)
    # Set the x-axis label
    plt.xlabel('Time Steps')
    # Set the y-axis label
    plt.ylabel('Tank Level')
    # Set the title for the subplot
    plt.title(tank_name)
    # Show the legend
    plt.legend()

# %%
(np.array(X_post_list)[:, 0]).shape
# Out:
# (6,)

# %%
z_true[:,:1].shape
# Out:
# (10001, 1)

# %% [markdown]
# X_POST PLOT

# %%
# Initialize the plot for original data and Kalman filter results
plt.figure(figsize=(12, 8))
# plt.suptitle(f'Original and Kalman Filter Results for tuner noice : {i} & tuner error covariance : {j}')

Plot_graphs(1, time_steps, z_true[:,:1], np.array(X_post_list)[:, 0], z_true[:,:1], 'Tank 1', '+')
Plot_graphs(2, time_steps, z_true[:,1:2], np.array(X_post_list)[:, 1], z_true[:,1:2], 'Tank 2', 'o')
Plot_graphs(3, time_steps, z_true[:,2:3], np.array(X_post_list)[:, 2], z_true[:,2:3], 'Tank 3', 's')
Plot_graphs(4, time_steps, z_true[:,3:4], np.array(X_post_list)[:, 3], z_true[:,3:4], 'Tank 4', 'x')

# Adjust the subplot layout, so the plots do not overlap
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# X_PRI PLOT

# %%
# Initialize the plot for original data and Kalman filter results
plt.figure(figsize=(12, 8))
# plt.suptitle(f'Original and Kalman Filter Results for tuner noice : {i} & tuner error covariance : {j}')

Plot_graphs(1, time_steps, z_true[:,:1], np.array(X_pri_list)[:, 0], z_true[:,:1], 'Tank 1', '+')
Plot_graphs(2, time_steps, z_true[:,1:2], np.array(X_pri_list)[:, 1], z_true[:,1:2], 'Tank 2', 'o')
Plot_graphs(3, time_steps, z_true[:,2:3], np.array(X_pri_list)[:, 2], z_true[:,2:3], 'Tank 3', 's')
Plot_graphs(4, time_steps, z_true[:,3:4], np.array(X_pri_list)[:, 3], z_true[:,3:4], 'Tank 4', 'x')

# Adjust the subplot layout, so the plots do not overlap
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# P_PRIOR PLOT

# %%
#  P_prior matrix's trace plot
P_prior_plot = [P_pri_list[i] for i in time_steps]

plt.plot(time_steps,P_prior_plot)
plt.title("Process Noise covariance trace")
plt.xlabel('Time step')
plt.ylabel('Trace of the prior process noise covariance matrix')
plt.show()

# %% [markdown]
# P_POST PLOT

# %%
#  P_post matrix's trace plot
P_post_plot = [P_post_list[i] for i in time_steps]

plt.plot(time_steps,P_post_plot)
plt.title("Process Noise covariance Posterior trace")
plt.xlabel('Time step')
plt.ylabel('Trace of the posterior process noise covariance matrix')
plt.show()

# %% [markdown]
# KALMAN GAIN MATRIX PLOT

# %%
# KALMAN_GAIN trace plot
Kalman_gain_plot = [Kalman_gain_list[i] for i in time_steps]

plt.plot(time_steps,Kalman_gain_plot)
plt.title("Kalman Gain Trace")
plt.xlabel('Time step')
plt.ylabel('Trace of Kalman gain matrix')
plt.show()

# %% [markdown]
# INNOVATOR TRACE PLOT

# %%
# KALMAN_GAIN trace plot
Innovator_plot_tank_one = [Innovation_store_list[i][0] for i in time_steps]

plt.plot(time_steps,Innovator_plot_tank_one)
plt.title("Innovaton Trace for Tank 1")
plt.xlabel('Time step')
plt.ylabel('Trace of Innovation matrix')
plt.show()

# KALMAN_GAIN trace plot
Innovator_plot_tank_two = [Innovation_store_list[i][1] for i in time_steps]

plt.plot(time_steps,Innovator_plot_tank_two)
plt.title("Innovaton Trace for Tank 2")
plt.xlabel('Time step')
plt.ylabel('Trace of Innovation matrix')
plt.show()

# %% [markdown]
# RESIDUE PLOT

# %%
# Residue plot
Residue_plot_tank_one = [Residue_store_list[i][0][0] for i in time_steps]

plt.plot(time_steps,Residue_plot_tank_one)
plt.title("Residue Plot for Tank 1")
plt.xlabel('Time step')
plt.ylabel('first tank height residue')
plt.show()

# Residue Plot for Tank 2
Residue_plot_tank_two = [Residue_store_list[i][1][0] for i in time_steps]

plt.plot(time_steps,Residue_plot_tank_two)
plt.title("Residue Plot for Tank 2")
plt.xlabel('Time step')
plt.ylabel('second tank height residue')
plt.show()
