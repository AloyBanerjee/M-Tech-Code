# %% [markdown]
# # <div align='center'> **Fault Detection**

# %%
# Importing necessary libraries

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import patches
import seaborn as sns
from sklearn import datasets
from sklearn import preprocessing
from scipy.stats import f
import pandas as pd
from sklearn.decomposition import PCA
from scipy.stats import chi2
from matplotlib.patches import Ellipse
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd

# %% [markdown]
# # <div align='center'> **Visualizing the Features of the Iris dataset**

# %%
# Load the Iris dataset from seaborn
iris_data = sns.load_dataset("iris")

# Define the features and their labels
features = {
    'sepal_length': 'Sepal Length',
    'sepal_width': 'Sepal Width',
    'petal_length': 'Petal Length',
    'petal_width': 'Petal Width'
}
# Create a single plot for all features
plt.figure(figsize=(12, 8))

# Iterate through the features and plot scatter plots
for feature, label in features.items():
    plt.scatter(iris_data.index, iris_data[feature], label=label)

# Add legends and labels
plt.legend(title='Features')
plt.xlabel('Observations')
plt.ylabel('Measurement')
plt.title('Iris Dataset - Scatter Plot of Features')

# Draw dotted lines to separate classes
for index in [49.5, 99.5]:
    plt.axvline(index, color='black', linestyle='dotted')

# Add class labels
class_labels = ['Setosa', 'Versicolor', 'Virginica']
for i, label in enumerate(class_labels):
    plt.text(24.75 + i * 49.75, 8, label, ha='center', va='bottom', color=['red', 'green', 'blue'][i], fontweight='bold')

# Show the plot
plt.show()

# %%
# Basic statistics
# Group the data by the 'species' column
grouped_data = iris_data.groupby('species')

# Calculate the mean for each class
mean_values = grouped_data.mean().transpose()
print("Mean values:\n", mean_values)

# Calculate the standard deviation for each class
std_values = grouped_data.std().transpose()
print("Standard deviation values:\n", std_values)
# Out:
# Mean values:
#  species       setosa  versicolor  virginica
# sepal_length   5.006       5.936      6.588
# sepal_width    3.428       2.770      2.974
# petal_length   1.462       4.260      5.552
# petal_width    0.246       1.326      2.026
# Standard deviation values:
#  species         setosa  versicolor  virginica
# sepal_length  0.352490    0.516171   0.635880
# sepal_width   0.379064    0.313798   0.322497
# petal_length  0.173664    0.469911   0.551895
# petal_width   0.105386    0.197753   0.274650

# %%
# Create a single plot for all pairwise scatter plots
sns.pairplot(iris_data, hue='species')

# %% [markdown]
# # <div align='center'> **$T^{2}$ Statistics**
# - $T^{2}$ statistic is used to detect faults in multivariate process data.
# - Assumption: $\Lambda = \Sigma^{T} \Sigma$ is invertible.

# %%
# Defining the dependent and independent variables
iris = datasets.load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Filter data points for class 3 (Iris Setosa)
class_3_indices = np.where(y == 0)
X_class_3 = X[class_3_indices]
y_class_3 = y[class_3_indices]

# %%
# Autoscaling and visualization
X_scaled = preprocessing.scale(X_class_3)

# Plot histograms
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot original data
axes[0].hist(X_class_3.flatten(), bins=20, color='blue', alpha=0.5)
axes[0].set_title('Original Data')

# Plot autoscaled data
axes[1].hist(X_scaled.flatten(), bins=20, color='red', alpha=0.5)
axes[1].set_title('Autoscaled Data')

# Set plot labels and layout
plt.tight_layout()
plt.show()

# %%
# Calculating sample covariance
cov_matrix = np.cov(X_scaled.T)
cov_matrix
# Out:
# array([[1.02040816, 0.7577007 , 0.27262833, 0.28377383],
#        [0.7577007 , 1.02040816, 0.1813265 , 0.23750205],
#        [0.27262833, 0.1813265 , 1.02040816, 0.338398  ],
#        [0.28377383, 0.23750205, 0.338398  , 1.02040816]])

# %%
# # Calculating sample covariance (manually)
# cov_matrix = 1/(50-1) * X_scaled.T@X_scaled
# print("The covariance calculated using tools is:\n",cov_matrix)

# %%
# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

print("Diagonal matrix of eigenvalues (Lambda):\n", Lambda)

# Print the eigenvalues and eigenvectors
for i in range(len(eigenvalues_sorted)):
    print("Eigenvalue", i+1, ":", eigenvalues_sorted[i])
    print("Eigenvector", i+1, ":", eigenvectors_sorted[:, i])
    print()
# Out:
# Diagonal matrix of eigenvalues (Lambda):
#  [[2.10055124 0.         0.         0.        ]
#  [0.         1.04303902 0.         0.        ]
#  [0.         0.         0.68144923 0.        ]
#  [0.         0.         0.         0.25659316]]
# Eigenvalue 1 : 2.100551239906338
# Eigenvector 1 : [0.6044164  0.57561937 0.37543478 0.40297876]
#
# Eigenvalue 2 : 1.043039024650951
# Eigenvector 2 : [ 0.33499079  0.44084607 -0.6269717  -0.54803504]
#
# Eigenvalue 3 : 0.6814492293736025
# Eigenvector 3 : [-6.73598261e-02 -7.13823888e-04 -6.77062810e-01  7.32835654e-01]
#
# Eigenvalue 4 : 0.25659315913033176
# Eigenvector 4 : [ 0.71966982 -0.68870645 -0.08683986 -0.01475204]

# %% [markdown]
# ## For a given observation vector 'x', $T^{2}$ statistic is given by: $T^{2} = x^{T}V \Lambda^{-1}V^{T}x$

# %%
# Extracting a sample from the class 3 data
x= X_scaled[3, :].reshape((4,1))
x_T = np.transpose(X)
V = eigenvectors_sorted
V_T = eigenvectors_sorted.T

# Taking inverse of Lambda
Lambda_inv = np.diag(1 / np.diag(Lambda))

print("Diagonal matrix Lambda:\n", Lambda)
print("Inverse of Lambda:\n", Lambda_inv)
# Out:
# Diagonal matrix Lambda:
#  [[2.10055124 0.         0.         0.        ]
#  [0.         1.04303902 0.         0.        ]
#  [0.         0.         0.68144923 0.        ]
#  [0.         0.         0.         0.25659316]]
# Inverse of Lambda:
#  [[0.47606551 0.         0.         0.        ]
#  [0.         0.9587369  0.         0.        ]
#  [0.         0.         1.46746075 0.        ]
#  [0.         0.         0.         3.89722003]]

# %%
#Calculating T squared
T_2 = x.T@V@Lambda_inv@V.T@x
print("T squared:", T_2)
# Out:
# T squared: [[1.70620698]]

# %%
# Calculating the Hotelling's T-squared statistic with loading matrix
P = eigenvectors_sorted[:, :2]
print("Loading matrix:\n", P)

lambda_sel = np.diag(eigenvalues_sorted)[:2, :2]
lambda_sel_inv = np.linalg.inv(lambda_sel)
T_2_P = x.T@P@lambda_sel_inv@P.T@x
print("T squared:", T_2_P)
# Out:
# Loading matrix:
#  [[ 0.6044164   0.33499079]
#  [ 0.57561937  0.44084607]
#  [ 0.37543478 -0.6269717 ]
#  [ 0.40297876 -0.54803504]]
# T squared: [[1.23887184]]

# %% [markdown]
# # <div align='center'> **$T^{2}$ Statistic Threshold**
# If the actual mean and co-variance are known, then the $T^{2}$ statistic thereshold for a confidence level is given by: $\chi_{\alpha} ^{2}(a)$

# %%
# Autoscale the iris data
X_scaled1 = preprocessing.scale(X)

# Plot histograms
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot original data
axes[0].hist(X.flatten(), bins=20, color='blue', alpha=0.5)
axes[0].set_title('Original Data')

# Plot autoscaled data
axes[1].hist(X_scaled1.flatten(), bins=20, color='red', alpha=0.5)
axes[1].set_title('Autoscaled Data')

# Set plot labels and layout
plt.tight_layout()
plt.show()

# %%
# Performimg PCA to reduce the dimensionality to 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled1)
y_labels = [target_names[i] for i in y]


# Calculating the T2 threshold for class 3 data
class3_indices = np.where(y == 0)[0]
class3_data = X_pca[class3_indices, :]
confidence_level = 0.95
threshold = chi2.ppf(confidence_level, df=2)

# Creating a scatter plot of the transformed data
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y_labels,)

# Adding the T2 threshold ellipse for class 3 data
ellipse = Ellipse(xy=np.mean(class3_data, axis=0), width=2 * np.sqrt(threshold) * np.sqrt(pca.explained_variance_ratio_[0]),
                  height=2 * np.sqrt(threshold) * np.sqrt(pca.explained_variance_ratio_[1]), edgecolor='red', facecolor='none',
                  label='Class 3 $T^2$ Threshold')

# Adding the ellipse to the plot
plt.gca().add_patch(ellipse)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of Iris Dataset')
plt.legend()

# Show the plot
plt.show()

# %%
# Calculating T2 statistic threshold when sample covariance is used

# calcualting F_alpha(a,n-a) = (a = 2, n-a = 48) with alpha = 0.05 (confidence interval)
alpha = 0.05  # Significance level
dfn = 2  # Degrees of freedom numerator
dfd = 48  # Degrees of freedom denominator

critical_value = f.ppf(1 - alpha, dfn, dfd)

print("Critical value F_alpha(a, n-a):", critical_value)
# Out:
# Critical value F_alpha(a, n-a): 3.190727335928499

# %%
# Calculating T^2 statistic threshold
n = 50
a = 2
T_2_alpha = ((a * (n - 1) * (n + 1)) / (n * (n - a))) * critical_value
print("T^2 threshold:", T_2_alpha)
# Out:
# T^2 threshold: 6.644689677071099

# %% [markdown]
# # <div align='center'> **Outliers in Training Set**
# - Outliers in the training set can be detected using the $T^{2}$ statistic for a selected confidence level = $\frac{(n-1)^{2}(a/(n-a-1))F_{\alpha}(a, n-a-1)}{n(1+(a/(n-a-1))F_{\alpha}(a,n-a-1))}$

# %%
alpha = 0.05  # Significance level

# Calculate F_alpha(a, n-a-1)
f_alpha = f.ppf(alpha, a, n - a - 1)

# Calculate T^2 statistic
threshold_outl= ((n - 1) ** 2 * (a / (n - a - 1)) * f_alpha) / (n * (1 + (a / (n - a - 1))) * f_alpha)
threshold_outl
# Out:
# 1.9599999999999997

# %%
t_squared_values = []
for i in range(len(X_scaled)):
    x= X_scaled[i, :].reshape((4,1))
    t_squared = x.T@V@Lambda_inv@V.T@x
    t_squared_values.append(t_squared)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(t_squared_values)), t_squared_values, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=threshold, linestyle='dotted', color='red', label='Threshold')

# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Outlier Detection using $T^2$ Statistic')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # <div align='center'> **Q - Statistics**
#
# - Measures the deviation of the observations to the lower dimensional PCA representation

# %%
I = np.identity(4)
# calculating Residual vector
Q_stat_values = []
for data_point in X_scaled1:
    # calculating Residual vector
    r = (I - P @ P.T) @ data_point.reshape((4,1))

    # calculating Q statistic
    Q = r.T @ r
    Q_stat_values.append(Q)

# converting the Q statistics to a numpy array
Q_stat_values = np.array(Q_stat_values)

# Printing the Q statistics
print("The Q statistics are:\n", Q_stat_values)
# Out:
# The Q statistics are:
#  [[[1.47428645e+00]]
#
#  [[3.55527910e-01]]
#
#  [[1.17732199e+00]]
#
#  [[1.04245139e+00]]
#
#  [[2.13154260e+00]]
#
#  [[2.58053211e+00]]
#
#  [[2.25068022e+00]]
#
#  [[1.31815386e+00]]
#
#  [[7.66563637e-01]]
#
#  [[5.86852508e-01]]
#
#  [[1.62821473e+00]]
#
#  [[1.76368021e+00]]
#
#  [[4.68587117e-01]]
#
#  [[1.22303308e+00]]
#
#  [[1.92318699e+00]]
#
#  [[4.53418009e+00]]
#
#  [[2.55837011e+00]]
#
#  [[1.48895859e+00]]
#
#  [[1.40456663e+00]]
#
#  [[2.88245541e+00]]
#
#  [[6.72869627e-01]]
#
#  [[2.39668376e+00]]
#
#  [[3.23968533e+00]]
#
#  [[8.73825367e-01]]
#
#  [[1.82783459e+00]]
#
#  [[2.73101478e-01]]
#
#  [[1.35405271e+00]]
#
#  [[1.28314453e+00]]
#
#  [[9.37933395e-01]]
#
#  [[1.20561354e+00]]
#
#  [[7.27434396e-01]]
#
#  [[6.62427438e-01]]
#
#  [[4.35127758e+00]]
#
#  [[3.90218330e+00]]
#
#  [[5.76991567e-01]]
#
#  [[6.73630133e-01]]
#
#  [[7.40472701e-01]]
#
#  [[2.39354956e+00]]
#
#  [[1.06464157e+00]]
#
#  [[1.12608437e+00]]
#
# ...

# %% [markdown]
# # Q statistic distribution is approximated as
# $Q_{\alpha} = \theta_{1}[\frac{h_{0}c_{\alpha}\sqrt{2\theta_{2}}}{\theta_{1}} + 1 + \frac{\theta_{2}h_{0}(h_{0}-1)}{\theta_{1}^{2}}]^{1/h_{0}}$
# where:<br>
# $\theta_{i} = \sum_{j=a+1}^{n}\sigma_{j}^{2i}$ and<br> $h_{0} = 1- \frac {2\theta_{1}\theta_{3}}{3\theta_{2}^{2}}$

# %%
# Number of eigenvalues
n = 4
# Define the number of excluded principal components (k)
k = 2
# Determine the value of a
a = X.shape[1] - k
# Perform the manual calculation for θ
theta_1 = 0
i = 1  # Set i to 1
for j in range(a + 1, len(eigenvalues_sorted)):
    theta_1 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_1:", theta_1)

# Perform the manual calculation for θᵢ
theta_2 = 0
i = 2  # Set i to 1
for j in range(a + 1, len(eigenvalues_sorted)):
    theta_2 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_2:", theta_2)

# Perform the manual calculation for θᵢ
theta_3 = 0
i = 3  # Set i to 1
for j in range(a + 1, len(eigenvalues_sorted)):
    theta_3 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_3:", theta_3)
# Out:
# θ_1: 0.06584004931248376
# θ_2: 0.004334912093470293
# θ_3: 0.0002854108259993663

# %%
h_0 = 1 - (2 * theta_1 * theta_3) / (3 * theta_2**2)
print("h_0:", h_0)
# Out:
# h_0: 0.33333333333333337

# %%
from scipy.stats import norm

alpha = 0.05  # Significance level (e.g., 0.05 for a 95% confidence level)
c_alpha = norm.ppf(1 - alpha)  # Calculate ca

print("ca:", c_alpha)
# Out:
# ca: 1.6448536269514722

# %%
import math
# Calculate Q_alpha
Q_alpha = theta_1 * math.pow((h_0 * c_alpha * math.sqrt(2 * theta_2) / theta_1) + 1 + (theta_2 * h_0 * (h_0 - 1)) / (theta_1 ** 2), 1 / h_0)

print("Q_alpha:", Q_alpha)
# Out:
# Q_alpha: 0.2466871161711274

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size
plt.scatter(range(len(Q_stat_values)), Q_stat_values, label='Q Statistic', marker='o', color='blue', edgecolors='black', s=50)

# Plot the threshold as a dotted line
plt.axhline(y=Q_alpha, linestyle='dotted', color='red', label='Threshold')

# Add x and y-axis labels
plt.xlabel('Data Points')
plt.ylabel('Q Statistic')
plt.title('Scatter Plot of Q Statistic')

# Enable grid lines
plt.grid(True)
plt.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# # Dataset for Practice
# - Palmer Penguins dataset.
# - Use the following command to install the package:
#     - *pip install palmerpenguins*
#     - *from palmerpenguins import load_penguins*

# %%
pip install palmerpenguins
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from palmerpenguins import load_penguins

# %%
penguin_data = load_penguins()

# %%
penguin_data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguin_data.dropna(inplace=True)

# %%
sns.pairplot(penguin_data, hue='species',palette='coolwarm')

# %%
penguin_data.drop(columns=['island','sex','year'],inplace=True)

# %%
penguin_data.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0  Adelie            39.1           18.7              181.0       3750.0
# 1  Adelie            39.5           17.4              186.0       3800.0
# 2  Adelie            40.3           18.0              195.0       3250.0
# 4  Adelie            36.7           19.3              193.0       3450.0
# 5  Adelie            39.3           20.6              190.0       3650.0

# %%
sns.pairplot(penguin_data, hue='species',palette='coolwarm')

# %%
sns.countplot(x='species',data=penguin_data)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
penguin_data['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguin_data.columns
# Out:
# Index(['species', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm',
#        'body_mass_g'],
#       dtype='object')

# %%
# Define the features and their labels
features = {
    'bill_length_mm': 'Bill Length',
    'bill_depth_mm': 'Bill Depth',
    'flipper_length_mm': 'Flipper Length',
    'body_mass_g': 'Body Mass'
}
# Create a single plot for all features
plt.figure(figsize=(12, 8))

# Iterate through the features and plot scatter plots
for feature, label in features.items():
    plt.scatter(penguin_data.index, penguin_data[feature], label=label)

# Add legends and labels
plt.legend(title='Features')
plt.xlabel('Observations')
plt.ylabel('Measurement')
plt.title('penguin Dataset - Scatter Plot of Features')

# Draw dotted lines to separate classes
for index in [146, 265]:
    plt.axvline(index, color='black', linestyle='dotted')

# Add class labels
class_labels = ['Adelie', 'Gentoo', 'Chinstrap']
for i, label in enumerate(class_labels):
    plt.text(24.75 + i * 146, 6350, label, ha='center', va='bottom', color=['red', 'green', 'blue'][i], fontweight='bold')

# Show the plot
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
# Defining the dependent and independent variables
X = penguin_data.drop(axis=1,columns='species')
y = penguin_data['species']

X_arr = np.array(X)

# %%
# Autoscaling and visualization
X_scaled = preprocessing.scale(X_arr)

# Plot histograms
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Plot original data
axes[0].hist(X_arr.flatten(), bins=20, color='blue', alpha=0.5)
axes[0].set_title('Original Data')

# Plot autoscaled data
axes[1].hist(X_scaled.flatten(), bins=20, color='red', alpha=0.5)
axes[1].set_title('Autoscaled Data')

# Set plot labels and layout
plt.tight_layout()
plt.show()

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y ,random_state=42, test_size=0.2)

# %%
X_train_scaled = preprocessing.scale(X_train)
X_test_scaled = preprocessing.scale(X_test)

# %%
from tsquared import HotellingT2
clf = HotellingT2()

# Hotelling's T2 without dataset cleaning.
clf.fit(X_train_scaled)
t_scores_test = clf.score_samples(X_test_scaled)
t_scores_train = clf.score_samples(X_train_scaled)

# %%
len(t_scores_test)+1
# Out:
# 68

# %%
plt.scatter(range(1,len(t_scores_train)+1),t_scores_train,label='Train data T squared')
plt.scatter(range(len(t_scores_train)+1,len(t_scores_train)+len(t_scores_test)+1),t_scores_test,label='Test data T squared')
plt.legend()

# %%
# Calculating sample covariance
cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted
V_T = eigenvectors_sorted.T

# %%
t_squared_values_train = []
for i in range(len(X_train_scaled)):
    x= X_train_scaled[i, :].reshape((4,1))
    t_squared = x.T@V@Lambda_inv@V.T@x
    t_squared_values_train.append(t_squared)

# %%
# Calculating sample covariance
cov_matrix = np.cov(X_test_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted
V_T = eigenvectors_sorted.T

# %%
t_squared_values_test = []
for i in range(len(X_test_scaled)):
    x= X_test_scaled[i, :].reshape((4,1))
    t_squared = x.T@V@Lambda_inv@V.T@x
    t_squared_values_test.append(t_squared)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(t_squared_values_train)), t_squared_values_train, label='$T^2$ train Statistic')
plt.scatter(range(len(t_squared_values_train),len(t_squared_values_train)+len(t_squared_values_test)), t_squared_values_test, label='$T^2$ test Statistic')

# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title(' $T^2$ Statistic on train and test data')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Performimg PCA on whole train data
pca = PCA()
X_pca = pca.fit_transform(X_train_scaled)
print(np.cumsum(pca.explained_variance_ratio_[0:]*100))
plt.plot(range(1,5),np.cumsum(pca.explained_variance_ratio_[0:]*100))
plt.axhline(y=95,color='r',linestyle='--',label='95% threshold')
plt.xlabel('No of PCs')
plt.ylabel('Cumulative Variance explained')
plt.legend()
# Out:
# [ 69.72530516  88.67681224  97.24344694 100.        ]

# %%
# We can conclude from above graph that 3 PCs are required for > 95% variance explanation

# %%
# Assuming that the T^2 statistic follows a χ^2 distribution
confidence_level = 0.9
threshold = chi2.ppf(confidence_level, df=3)
threshold
# Out:
# 6.251388631170325

# %%
# using sample covariance and calculating for each type (seed1)

alpha = 0.1  # Significance level
dfn = 3  # Degrees of freedom numerator
dfd = X_test_scaled.shape[0] - dfn # Degrees of freedom denominator

critical_value = f.ppf(1-alpha, dfn, dfd)

print("Critical value F_alpha(a, n-a):", critical_value)


# Calculating T^2 statistic threshold
n = X_test_scaled.shape[0]
a = 3
T_2_alpha = ((a * (n - 1) * (n + 1)) / (n * (n - a))) * critical_value
print("T^2 threshold:", T_2_alpha)
# Out:
# Critical value F_alpha(a, n-a): 2.171415306721553
# T^2 threshold: 6.8180820171872645

# %%
cov_matrix = np.cov(X_test_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_test_scaled.T)
T_squared_test = np.diag(Z_test.T@Z_test)

alpha = 0.1  # Significance level
dfn = 3  # Degrees of freedom numerator
dfd = X_test_scaled.shape[0] - dfn  # Degrees of freedom denominator

critical_value = f.ppf(1 - alpha, dfn, dfd)

# Calculating T^2 statistic threshold
n = X_test_scaled.shape[0]
a = 3
T_2_alpha = ((a * (n - 1) * (n + 1)) / (n * (n - a))) * critical_value

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=T_2_alpha, linestyle='dotted', color='red', label='Threshold')
#plt.axhline(y=threshold_outl, linestyle='dotted', color='green', label='outlier threshold')


# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Fault Detection using $T^2$ Statistic')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# # species wise fault detection

# %%
species_1_indices = np.where(y_test == 'Adelie')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=T_2_alpha, linestyle='dotted', color='red', label='Threshold')
#plt.axhline(y=threshold_outl, linestyle='dotted', color='green', label='outlier threshold')


# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Fault Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
species_1_indices = np.where(y_test == 'Gentoo')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=T_2_alpha, linestyle='dotted', color='red', label='Threshold')
#plt.axhline(y=threshold_outl, linestyle='dotted', color='green', label='outlier threshold')


# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Fault Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
species_1_indices = np.where(y_test == 'Chinstrap')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=T_2_alpha, linestyle='dotted', color='red', label='Threshold')
#plt.axhline(y=threshold_outl, linestyle='dotted', color='green', label='outlier threshold')


# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Fault Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
pca = PCA(n_components=3)

species_1_indices = np.where(y_test == 'Adelie')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

X_pca = pca.fit_transform(X_seed_1)
y_labels = [i for i in y_seed_1]

# Creating a scatter plot of the transformed data
sns.scatterplot(x=X_pca[:, 0].T, y=X_pca[:, 1].T, hue=y_labels)

# Adding the T2 threshold ellipse for class 3 data
ellipse = Ellipse(xy=np.mean(X_pca.T, axis=0), width=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[0]),
                  height=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[1]), edgecolor='red', facecolor='none',
                  label='Seed 1 $T^2$ Threshold')

# Adding the ellipse to the plot
plt.gca().add_patch(ellipse)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of the seeds dataset for seed 1')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
pca = PCA(n_components=3)

species_1_indices = np.where(y_test == 'Gentoo')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

X_pca = pca.fit_transform(X_seed_1)
y_labels = [i for i in y_seed_1]

# Creating a scatter plot of the transformed data
sns.scatterplot(x=X_pca[:, 0].T, y=X_pca[:, 1].T, hue=y_labels)

# Adding the T2 threshold ellipse for class 3 data
ellipse = Ellipse(xy=np.mean(X_pca.T, axis=0), width=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[0]),
                  height=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[1]), edgecolor='red', facecolor='none',
                  label='Seed 1 $T^2$ Threshold')

# Adding the ellipse to the plot
plt.gca().add_patch(ellipse)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of the seeds dataset for seed 1')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
pca = PCA(n_components=3)

species_1_indices = np.where(y_test == 'Chinstrap')
X_seed_1 = X_test_scaled[species_1_indices]
y_seed_1 = y_test.iloc[species_1_indices]

X_pca = pca.fit_transform(X_seed_1)
y_labels = [i for i in y_seed_1]

# Creating a scatter plot of the transformed data
sns.scatterplot(x=X_pca[:, 0].T, y=X_pca[:, 1].T, hue=y_labels)

# Adding the T2 threshold ellipse for class 3 data
ellipse = Ellipse(xy=np.mean(X_pca.T, axis=0), width=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[0]),
                  height=2 * np.sqrt(T_2_alpha) * np.sqrt(pca.explained_variance_ratio_[1]), edgecolor='red', facecolor='none',
                  label='Seed 1 $T^2$ Threshold')

# Adding the ellipse to the plot
plt.gca().add_patch(ellipse)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA of the seeds dataset for seed 1')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
# Calculating sample covariance

alpha = 0.1  # Significance level 

seed_1_indices = np.where(y_train == 'Adelie')
X_seed_1 = X_train_scaled[seed_1_indices]
y_seed_1 = y_train.iloc[seed_1_indices]

n=X_seed_1.shape[0]
a=3

# Calculate F_alpha(a, n-a-1)
f_alpha = f.ppf(1-alpha, a, n - a - 1)

# Calculate T^2 statistic
threshold_outl= ((n - 1) ** 2 * (a / (n - a - 1)) * f_alpha) / (n * (1 + (a / (n - a - 1))))

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=threshold_outl, linestyle='dotted', color='red', label='Threshold')

# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Outlier Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
# Calculating sample covariance

alpha = 0.1  # Significance level 

seed_1_indices = np.where(y_train == 'Gentoo')
X_seed_1 = X_train_scaled[seed_1_indices]
y_seed_1 = y_train.iloc[seed_1_indices]

n=X_seed_1.shape[0]
a=3

# Calculate F_alpha(a, n-a-1)
f_alpha = f.ppf(1-alpha, a, n - a - 1)

# Calculate T^2 statistic
threshold_outl= ((n - 1) ** 2 * (a / (n - a - 1)) * f_alpha) / (n * (1 + (a / (n - a - 1))))

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=threshold_outl, linestyle='dotted', color='red', label='Threshold')

# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Outlier Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %%
# Calculating sample covariance

alpha = 0.1  # Significance level 

seed_1_indices = np.where(y_train == 'Chinstrap')
X_seed_1 = X_train_scaled[seed_1_indices]
y_seed_1 = y_train.iloc[seed_1_indices]

n=X_seed_1.shape[0]
a=3

# Calculate F_alpha(a, n-a-1)
f_alpha = f.ppf(1-alpha, a, n - a - 1)

# Calculate T^2 statistic
threshold_outl= ((n - 1) ** 2 * (a / (n - a - 1)) * f_alpha) / (n * (1 + (a / (n - a - 1))))

cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

Lambda = np.diag(eigenvalues_sorted)

Lambda_inv = np.diag(1 / np.diag(Lambda))

V = eigenvectors_sorted

Z_test = ((np.linalg.inv(np.sqrt(Lambda[:3,:3]))).dot(eigenvectors_sorted[:, :3].T)).dot(X_seed_1.T)
T_squared_test = np.diag(Z_test.T@Z_test)

# Create a scatter plot of the T^2 statistic values
plt.scatter(range(len(T_squared_test)), T_squared_test, label='$T^2$ Statistic')

# Plot the threshold as a dotted line
plt.axhline(y=threshold_outl, linestyle='dotted', color='red', label='Threshold')

# Add labels and title to the plot
plt.xlabel('Data Point')
plt.ylabel('$T^2$ Statistic')
plt.title('Outlier Detection using $T^2$ Statistic for seed 1')

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# # Q statistic

# %%
cov_matrix = np.cov(X_train_scaled.T)

# Perform eigenvalue decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)


# Sort eigenvalues and eigenvectors in descending order
eigenvalue_indices = np.argsort(eigenvalues)[::-1]
eigenvalues_sorted = eigenvalues[eigenvalue_indices]
eigenvectors_sorted = eigenvectors[:, eigenvalue_indices]

# %%
P = eigenvectors_sorted[:, :3]

# %%
I = np.identity(4)
# calculating Residual vector
Q_stat_values = []
for data_point in X_train_scaled:
    # calculating Residual vector
    r = (I - P @ P.T) @ data_point.reshape((4,1))

    # calculating Q statistic
    Q = r.T @ r
    Q_stat_values.append(Q)

# converting the Q statistics to a numpy array
Q_stat_values = np.array(Q_stat_values)

# Printing the Q statistics
print("The Q statistics are:\n", Q_stat_values)
# Out:
# The Q statistics are:
#  [[[2.43074804e-03]]
#
#  [[8.51430071e-02]]
#
#  [[2.88966795e-04]]
#
#  [[3.14652494e-04]]
#
#  [[5.28753565e-01]]
#
#  [[8.01348863e-02]]
#
#  [[2.23746558e-01]]
#
#  [[1.06540337e-03]]
#
#  [[2.79711906e-01]]
#
#  [[2.24126738e-02]]
#
#  [[4.43614170e-01]]
#
#  [[1.67950529e-02]]
#
#  [[4.00513876e-03]]
#
#  [[5.61588502e-01]]
#
#  [[1.47953060e-01]]
#
#  [[1.87610931e-02]]
#
#  [[1.33544582e-03]]
#
#  [[1.77938465e-02]]
#
#  [[2.26892605e-03]]
#
#  [[1.34886571e-03]]
#
#  [[1.90214229e-05]]
#
#  [[9.19455610e-02]]
#
#  [[2.72809416e-03]]
#
#  [[1.76319166e-02]]
#
#  [[3.06008016e-02]]
#
#  [[1.11612749e-01]]
#
#  [[2.97892567e-02]]
#
#  [[8.43310715e-02]]
#
#  [[4.21649016e-01]]
#
#  [[1.05821688e-01]]
#
#  [[1.14917243e-01]]
#
#  [[7.61859889e-02]]
#
#  [[5.64290252e-02]]
#
#  [[1.15354981e-02]]
#
#  [[2.52034872e-01]]
#
#  [[9.87409672e-05]]
#
#  [[8.74313540e-02]]
#
#  [[2.88665939e-02]]
#
#  [[7.38923859e-02]]
#
#  [[1.74622262e-02]]
#
# ...

# %%
a
# Out:
# 3

# %%
# Number of eigenvalues
n = 4
# Define the number of excluded principal components (k)
k = 1
# Determine the value of a
a = X_train_scaled.shape[1] - k
# Perform the manual calculation for θ
theta_1 = 0
i = 1  # Set i to 1
for j in range(a, len(eigenvalues_sorted)):
    theta_1 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_1:", theta_1)

# Perform the manual calculation for θᵢ
theta_2 = 0
i = 2  # Set i to 1
for j in range(a, len(eigenvalues_sorted)):
    theta_2 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_2:", theta_2)

# Perform the manual calculation for θᵢ
theta_3 = 0
i = 3  # Set i to 1
for j in range(a, len(eigenvalues_sorted)):
    theta_3 = eigenvalues_sorted[j]**(2 * i)  # Use 2 * i as the power

print("θ_3:", theta_3)
# Out:
# θ_1: 0.012249665276539515
# θ_2: 0.0001500542993872579
# θ_3: 1.8381149407995576e-06

# %%
h_0 = 1 - (2 * theta_1 * theta_3) / (3 * theta_2**2)
print("h_0:", h_0)
# Out:
# h_0: 0.33333333333333337

# %%
from scipy.stats import norm

alpha = 0.05  # Significance level (e.g., 0.05 for a 95% confidence level)
c_alpha = norm.ppf(1 - alpha)  # Calculate ca

print("ca:", c_alpha)
# Out:
# ca: 1.6448536269514722

# %%
import math
# Calculate Q_alpha
Q_alpha = theta_1 * math.pow((h_0 * c_alpha * math.sqrt(2 * theta_2) / theta_1) + 1 + (theta_2 * h_0 * (h_0 - 1)) / (theta_1 ** 2), 1 / h_0)

print("Q_alpha:", Q_alpha)
# Out:
# Q_alpha: 0.04589660294434449

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size
plt.scatter(range(len(Q_stat_values)), Q_stat_values, label='Q Statistic', marker='o', color='blue', edgecolors='black', s=50)

# Plot the threshold as a dotted line
plt.axhline(y=Q_alpha, linestyle='dotted', color='red', label='Threshold')

# Add x and y-axis labels
plt.xlabel('Data Points')
plt.ylabel('Q Statistic')
plt.title('Scatter Plot of Q Statistic')

# Enable grid lines
plt.legend()

# Show the plot
plt.show()
